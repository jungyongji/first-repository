# %%
import nltk
nltk.download('stopwords')

import time
from tqdm import tqdm
import numpy as np
import pandas as pd
import os
import re
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
from bs4 import BeautifulSoup 
from tensorflow.keras.preprocessing.text import Tokenizer 
from tensorflow.keras.preprocessing.sequence import pad_sequences
import urllib.request
import warnings
warnings.filterwarnings("ignore", category=UserWarning, module='bs4')
# Out:
# [nltk_data] Downloading package stopwords to /aiffel/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
data = pd.read_csv(os.getenv("HOME")+"/aiffel/news_summarization/data/Reviews.csv", nrows=100000)
print('전체 샘플수 :', (len(data)))
# Out:
# 전체 샘플수 : 100000

# %%
data.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# 1      Not as Advertised  Product arrived labeled as Jumbo Salted Peanut...
# 2  "Delight" says it all  This is a confection that has been around a fe...
# 3         Cough Medicine  If you are looking for the secret ingredient i...
# 4            Great taffy  Great taffy at a great price.  There was a wid...

# %%
data = data[['Text','Summary']]
data.head()

#랜덤한 15개 샘플 출력
data.sample(15)
# Out:
#                                                     Text  \
# 5334   I can not believe that this is actually for sa...
# 75955  I have purchased this a few times (all flavors...
# 84140  These cherries are sour and chewy. Just writin...
# 31125  These popchips(original flavor)are great tasti...
# 23383  I used to feed my dachshund Bo a pig ear as a ...
# 50968  My cat eats well and has good digestion.  Last...
# 78102  This was a fantastic treat that was truly enjo...
# 22164  I have a 10 pound Yorkie who admittedly destro...
# 66181  These are great treats. I echo what other revi...
# 42620  I have ordered this item at least half dozen t...
# 73572  My kids have been drinking Rice Dream for two ...
# 65533  As a health nut, there's nothing like picking ...
# 70978  My husband's favorite coffee at Starbucks is P...
# 96578  These are the best pancakes ever. Not too swee...
# 28656  This coffee is amazing. I've tried multiple co...
#
#                                                  Summary
# 5334   SUGAR IS BAD FOR DOGS (First Ingredient is Sugar)
# 75955                           Love It Half Of The Time
# 84140                  Ya gotta love sours to love these
# 31125                                            Robsmom
# 23383                                      Pooch Pleaser
# 50968                                       Newman's Own
# 78102                                           sascat22
# 22164                                       Destructible
# 66181                  Great Treats! Our lab loves them.
# 42620                            Packing never a problem
# 73572                      Great product, poor packaging
# 65533                                Zesty and Flavorful
# 70978                                Good but not great.
# 96578                                      simply heaven
# 28656                               One of my favorites!

# %%
print('Text 열에서 중복을 배제한 유일한 샘플의 수 :', data['Text'].nunique())
print('Summary 열에서 중복을 배제한 유일한 샘플의 수 :', data['Summary'].nunique())
# Out:
# Text 열에서 중복을 배제한 유일한 샘플의 수 : 88426
# Summary 열에서 중복을 배제한 유일한 샘플의 수 : 72348

# %%
# inplace=True 를 설정하면 DataFrame 타입 값을 return 하지 않고 data 내부를 직접적으로 바꿉니다
data.drop_duplicates(subset = ['Text'], inplace=True)
print('전체 샘플수 :', (len(data)))
# Out:
# 전체 샘플수 : 88426

# %%
print(data.isnull().sum())
# Out:
# Text       0
# Summary    1
# dtype: int64

# %%
data.dropna(axis=0, inplace=True)
print('전체 샘플수 :', (len(data)))
# Out:
# 전체 샘플수 : 88425

# %%
contractions = {"ain't": "is not", "aren't": "are not","can't": "cannot", "'cause": "because", "could've": "could have", "couldn't": "could not",
                           "didn't": "did not",  "doesn't": "does not", "don't": "do not", "hadn't": "had not", "hasn't": "has not", "haven't": "have not",
                           "he'd": "he would","he'll": "he will", "he's": "he is", "how'd": "how did", "how'd'y": "how do you", "how'll": "how will", "how's": "how is",
                           "I'd": "I would", "I'd've": "I would have", "I'll": "I will", "I'll've": "I will have","I'm": "I am", "I've": "I have", "i'd": "i would",
                           "i'd've": "i would have", "i'll": "i will",  "i'll've": "i will have","i'm": "i am", "i've": "i have", "isn't": "is not", "it'd": "it would",
                           "it'd've": "it would have", "it'll": "it will", "it'll've": "it will have","it's": "it is", "let's": "let us", "ma'am": "madam",
                           "mayn't": "may not", "might've": "might have","mightn't": "might not","mightn't've": "might not have", "must've": "must have",
                           "mustn't": "must not", "mustn't've": "must not have", "needn't": "need not", "needn't've": "need not have","o'clock": "of the clock",
                           "oughtn't": "ought not", "oughtn't've": "ought not have", "shan't": "shall not", "sha'n't": "shall not", "shan't've": "shall not have",
                           "she'd": "she would", "she'd've": "she would have", "she'll": "she will", "she'll've": "she will have", "she's": "she is",
                           "should've": "should have", "shouldn't": "should not", "shouldn't've": "should not have", "so've": "so have","so's": "so as",
                           "this's": "this is","that'd": "that would", "that'd've": "that would have", "that's": "that is", "there'd": "there would",
                           "there'd've": "there would have", "there's": "there is", "here's": "here is","they'd": "they would", "they'd've": "they would have",
                           "they'll": "they will", "they'll've": "they will have", "they're": "they are", "they've": "they have", "to've": "to have",
                           "wasn't": "was not", "we'd": "we would", "we'd've": "we would have", "we'll": "we will", "we'll've": "we will have", "we're": "we are",
                           "we've": "we have", "weren't": "were not", "what'll": "what will", "what'll've": "what will have", "what're": "what are",
                           "what's": "what is", "what've": "what have", "when's": "when is", "when've": "when have", "where'd": "where did", "where's": "where is",
                           "where've": "where have", "who'll": "who will", "who'll've": "who will have", "who's": "who is", "who've": "who have",
                           "why's": "why is", "why've": "why have", "will've": "will have", "won't": "will not", "won't've": "will not have",
                           "would've": "would have", "wouldn't": "would not", "wouldn't've": "would not have", "y'all": "you all",
                           "y'all'd": "you all would","y'all'd've": "you all would have","y'all're": "you all are","y'all've": "you all have",
                           "you'd": "you would", "you'd've": "you would have", "you'll": "you will", "you'll've": "you will have",
                           "you're": "you are", "you've": "you have"}

print("정규화 사전의 수: ", len(contractions))
# Out:
# 정규화 사전의 수:  120

# %%
print('불용어 개수 :', len(stopwords.words('english') ))
print(stopwords.words('english'))
# Out:
# 불용어 개수 : 179
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
# 데이터 전처리 함수
def preprocess_sentence(sentence, remove_stopwords=True):
    sentence = sentence.lower() # 텍스트 소문자화
    sentence = BeautifulSoup(sentence, "lxml").text # <br />, <a href = ...> 등의 html 태그 제거
    sentence = re.sub(r'\([^)]*\)', '', sentence) # 괄호로 닫힌 문자열 (...) 제거 Ex) my husband (and myself!) for => my husband for
    sentence = re.sub('"','', sentence) # 쌍따옴표 " 제거
    sentence = ' '.join([contractions[t] if t in contractions else t for t in sentence.split(" ")]) # 약어 정규화
    sentence = re.sub(r"'s\b","", sentence) # 소유격 제거. Ex) roland's -> roland
    sentence = re.sub("[^a-zA-Z]", " ", sentence) # 영어 외 문자(숫자, 특수문자 등) 공백으로 변환
    sentence = re.sub('[m]{2,}', 'mm', sentence) # m이 3개 이상이면 2개로 변경. Ex) ummmmmmm yeah -> umm yeah
    
    # 불용어 제거 (Text)
    if remove_stopwords:
        tokens = ' '.join(word for word in sentence.split() if not word in stopwords.words('english') if len(word) > 1)
    # 불용어 미제거 (Summary)
    else:
        tokens = ' '.join(word for word in sentence.split() if len(word) > 1)
    return tokens

# %%
'''
word for word in sentence.split() if not word in stopwords.words('english') if len(word) > 1
for word in sentence.split():
    if len(word) > 1:
        if not word in stopwords.words('english'):
            print(word)
'''
# Out:
# "\nword for word in sentence.split() if not word in stopwords.words('english') if len(word) > 1\nfor word in sentence.split():\n    if len(word) > 1:\n        if not word in stopwords.words('english'):\n            print(word)\n"

# %%
temp_text = 'Everything I bought was great, infact I ordered twice and the third ordered was<br />for my mother and father.'
temp_summary = 'Great way to start (or finish) the day!!!'

print("text: ", preprocess_sentence(temp_text))
print("summary:", preprocess_sentence(temp_summary, False))  # 불용어를 제거하지 않습니다.
# Out:
# text:  everything bought great infact ordered twice third ordered wasfor mother father
# summary: great way to start the day

# %%
clean_text = []
# 전체 Text 데이터에 대한 전처리 : 10분 이상 시간이 걸릴 수 있습니다. 
for s in tqdm(data['Text']):
    clean_text.append(preprocess_sentence(s))

# 전처리 후 출력
print("Text 전처리 후 결과: ", clean_text[:5])
# Out:
# 100%|██████████| 88425/88425 [09:49<00:00, 150.10it/s]
# Text 전처리 후 결과:  ['bought several vitality canned dog food products found good quality product looks like stew processed meat smells better labrador finicky appreciates product better', 'product arrived labeled jumbo salted peanuts peanuts actually small sized unsalted sure error vendor intended represent product jumbo', 'confection around centuries light pillowy citrus gelatin nuts case filberts cut tiny squares liberally coated powdered sugar tiny mouthful heaven chewy flavorful highly recommend yummy treat familiar story lewis lion witch wardrobe treat seduces edmund selling brother sisters witch', 'looking secret ingredient robitussin believe found got addition root beer extract ordered made cherry soda flavor medicinal', 'great taffy great price wide assortment yummy taffy delivery quick taffy lover deal']

# %%
clean_summary = []
# 전체 Summary 데이터에 대한 전처리 : 5분 이상 시간이 걸릴 수 있습니다. 
for s in data['Summary']:
    clean_summary.append(preprocess_sentence(s, False))

print("Summary 전처리 후 결과: ", clean_summary[:5])
# Out:
# Summary 전처리 후 결과:  ['good quality dog food', 'not as advertised', 'delight says it all', 'cough medicine', 'great taffy']

# %%
data['Text'] = clean_text
data['Summary'] = clean_summary

# 빈 값을 Null 값으로 변환
data.replace('', np.nan, inplace=True)
# Out:
# =3

# %%
data.isnull().sum()
# Out:
# Text        0
# Summary    70
# dtype: int64

# %%
data.dropna(axis=0, inplace=True)
print('전체 샘플수 :', (len(data)))
# Out:
# 전체 샘플수 : 88355

# %%
# 길이 분포 출력
import matplotlib.pyplot as plt

text_len = [len(s.split()) for s in data['Text']]
summary_len = [len(s.split()) for s in data['Summary']]

print('텍스트의 최소 길이 : {}'.format(np.min(text_len)))
print('텍스트의 최대 길이 : {}'.format(np.max(text_len)))
print('텍스트의 평균 길이 : {}'.format(np.mean(text_len)))
print('요약의 최소 길이 : {}'.format(np.min(summary_len)))
print('요약의 최대 길이 : {}'.format(np.max(summary_len)))
print('요약의 평균 길이 : {}'.format(np.mean(summary_len)))

plt.subplot(1,2,1)
plt.boxplot(text_len)
plt.title('Text')
plt.subplot(1,2,2)
plt.boxplot(summary_len)
plt.title('Summary')
plt.tight_layout()
plt.show()

plt.title('Text')
plt.hist(text_len, bins = 40)
plt.xlabel('length of samples')
plt.ylabel('number of samples')
plt.show()

plt.title('Summary')
plt.hist(summary_len, bins = 40)
plt.xlabel('length of samples')
plt.ylabel('number of samples')
plt.show()
# Out:
# 텍스트의 최소 길이 : 2
# 텍스트의 최대 길이 : 1235
# 텍스트의 평균 길이 : 38.792428272310566
# 요약의 최소 길이 : 1
# 요약의 최대 길이 : 28
# 요약의 평균 길이 : 4.010729443721352

# %%
text_max_len = 50
summary_max_len = 8

# %%
def below_threshold_len(max_len, nested_list):
    cnt = 0
    for s in nested_list:
        if(len(s.split()) <= max_len):
            cnt = cnt + 1
    print('전체 샘플 중 길이가 %s 이하인 샘플의 비율: %s'%(max_len, (cnt / len(nested_list))))

# %%
below_threshold_len(text_max_len, data['Text'])
below_threshold_len(summary_max_len,  data['Summary'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/conda/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /opt/conda/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /opt/conda/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Text'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_65/223349538.py in <module>
# ----> 1 below_threshold_len(text_max_len, data['Text'])
#       2 below_threshold_len(summary_max_len,  data['Summary'])
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'Text'

# %%
data = data[data['Text'].apply(lambda x: len(x.split()) <= text_max_len)]
data = data[data['Summary'].apply(lambda x: len(x.split()) <= summary_max_len)]
print('전체 샘플수 :', (len(data)))
# Out:
# 전체 샘플수 : 65818

# %%
# 요약 데이터에는 시작 토큰과 종료 토큰을 추가한다.
data['decoder_input'] = data['Summary'].apply(lambda x : 'sostoken '+ x)
data['decoder_target'] = data['Summary'].apply(lambda x : x + ' eostoken')
data.head()
# Out:
#                                                 Text                Summary  \
# 0  bought several vitality canned dog food produc...  good quality dog food
# 1  product arrived labeled jumbo salted peanuts p...      not as advertised
# 2  confection around centuries light pillowy citr...    delight says it all
# 3  looking secret ingredient robitussin believe f...         cough medicine
# 4  great taffy great price wide assortment yummy ...            great taffy
#
#                     decoder_input                  decoder_target
# 0  sostoken good quality dog food  good quality dog food eostoken
# 1      sostoken not as advertised      not as advertised eostoken
# 2    sostoken delight says it all    delight says it all eostoken
# 3         sostoken cough medicine         cough medicine eostoken
# 4            sostoken great taffy            great taffy eostoken

# %%
encoder_input = np.array(data['Text']) # 인코더의 입력
decoder_input = np.array(data['decoder_input']) # 디코더의 입력
decoder_target = np.array(data['decoder_target']) # 디코더의 레이블

# %%
indices = np.arange(encoder_input.shape[0])
np.random.shuffle(indices)
print(indices)
# Out:
# [37325 40985 22257 ... 63891 13911   275]

# %%
encoder_input = encoder_input[indices]
decoder_input = decoder_input[indices]
decoder_target = decoder_target[indices]

# %%
n_of_val = int(len(encoder_input)*0.2)
print('테스트 데이터의 수 :', n_of_val)
# Out:
# 테스트 데이터의 수 : 13163

# %%
encoder_input_train = encoder_input[:-n_of_val]
decoder_input_train = decoder_input[:-n_of_val]
decoder_target_train = decoder_target[:-n_of_val]

encoder_input_test = encoder_input[-n_of_val:]
decoder_input_test = decoder_input[-n_of_val:]
decoder_target_test = decoder_target[-n_of_val:]

print('훈련 데이터의 개수 :', len(encoder_input_train))
print('훈련 레이블의 개수 :', len(decoder_input_train))
print('테스트 데이터의 개수 :', len(encoder_input_test))
print('테스트 레이블의 개수 :', len(decoder_input_test))
# Out:
# 훈련 데이터의 개수 : 52655
# 훈련 레이블의 개수 : 52655
# 테스트 데이터의 개수 : 13163
# 테스트 레이블의 개수 : 13163

# %%
src_tokenizer = Tokenizer() # 토크나이저 정의
src_tokenizer.fit_on_texts(encoder_input_train) # 입력된 데이터로부터 단어 집합 생성
print('=3')
src_tokenizer.word_index
# Out:
# =3
# {'like': 1,
#  'good': 2,
#  'great': 3,
#  'taste': 4,
#  'product': 5,
#  'love': 6,
#  'one': 7,
#  'flavor': 8,
#  'coffee': 9,
#  'would': 10,
#  'tea': 11,
#  'really': 12,
#  'get': 13,
#  'amazon': 14,
#  'best': 15,
#  'price': 16,
#  'buy': 17,
#  'much': 18,
#  'food': 19,
#  'time': 20,
#  'little': 21,
#  'use': 22,
#  'find': 23,
#  'tried': 24,
#  'better': 25,
#  'well': 26,
#  'also': 27,
#  'make': 28,
#  'chocolate': 29,
#  'try': 30,
#  'eat': 31,
#  'dog': 32,
#  'even': 33,
#  'bought': 34,
#  'delicious': 35,
#  'found': 36,
#  'order': 37,
#  'sweet': 38,
#  'could': 39,
#  'tastes': 40,
#  'drink': 41,
#  'recommend': 42,
#  'cup': 43,
#  'used': 44,
#  'loves': 45,
#  'sugar': 46,
#  'bag': 47,
#  'favorite': 48,
#  'cannot': 49,
#  'store': 50,
#  'first': 51,
#  'nice': 52,
#  'free': 53,
#  'made': 54,
#  'way': 55,
#  'box': 56,
#  'go': 57,
#  'got': 58,
#  'perfect': 59,
#  'dogs': 60,
#  'mix': 61,
#  'easy': 62,
#  'water': 63,
#  'since': 64,
#  'day': 65,
#  'ordered': 66,
#  'think': 67,
#  'bit': 68,
#  'snack': 69,
#  'flavors': 70,
#  'two': 71,
#  'hot': 72,
#  'many': 73,
#  'give': 74,
#  'ever': 75,
#  'still': 76,
#  'never': 77,
#  'every': 78,
#  'makes': 79,
#  'treats': 80,
#  'right': 81,
#  'stuff': 82,
#  'quality': 83,
#  'always': 84,
#  'without': 85,
#  'brand': 86,
#  'know': 87,
#  'healthy': 88,
#  'years': 89,
#  'fresh': 90,
#  'tasty': 91,
#  'definitely': 92,
#  'want': 93,
#  'hard': 94,
#  'strong': 95,
#  'lot': 96,
#  'buying': 97,
#  'something': 98,
#  'add': 99,
#  'small': 100,
#  'old': 101,
#  'happy': 102,
#  'keep': 103,
#  'local': 104,
#  'enjoy': 105,
#  'less': 106,
#  'wonderful': 107,
#  'treat': 108,
#  'enough': 109,
#  'bad': 110,
#  'excellent': 111,
#  'different': 112,
#  'chips': 113,
#  'say': 114,
#  'milk': 115,
#  'highly': 116,
#  'organic': 117,
#  'need': 118,
#  'purchase': 119,
#  'shipping': 120,
#  'however': 121,
#  'far': 122,
#  'sure': 123,
#  'eating': 124,
#  'long': 125,
#  'size': 126,
#  'thought': 127,
#  'products': 128,
#  'regular': 129,
#  'looking': 130,
#  'back': 131,
#  'salt': 132,
#  'tasting': 133,
#  'tasted': 134,
#  'stores': 135,
#  'put': 136,
#  'though': 137,
#  'pack': 138,
#  'whole': 139,
#  'using': 140,
#  'purchased': 141,
#  'pretty': 142,
#  'bars': 143,
#  'loved': 144,
#  'bags': 145,
#  'cups': 146,
#  'work': 147,
#  'worth': 148,
#  'high': 149,
#  'package': 150,
#  'cookies': 151,
#  'low': 152,
#  'ingredients': 153,
#  'family': 154,
#  'arrived': 155,
#  'sauce': 156,
#  'texture': 157,
#  'green': 158,
#  'big': 159,
#  'gluten': 160,
#  'thing': 161,
#  'grocery': 162,
#  'last': 163,
#  'quite': 164,
#  'popcorn': 165,
#  'going': 166,
#  'received': 167,
#  'take': 168,
#  'year': 169,
#  'rice': 170,
#  'item': 171,
#  'candy': 172,
#  'actually': 173,
#  'came': 174,
#  'anything': 175,
#  'real': 176,
#  'almost': 177,
#  'cat': 178,
#  'see': 179,
#  'expensive': 180,
#  'feel': 181,
#  'natural': 182,
#  'oil': 183,
#  'dark': 184,
#  'calories': 185,
#  'husband': 186,
#  'butter': 187,
#  'new': 188,
#  'chicken': 189,
#  'cereal': 190,
#  'blend': 191,
#  'trying': 192,
#  'another': 193,
#  'full': 194,
#  'kids': 195,
#  'money': 196,
#  'coconut': 197,
#  'getting': 198,
#  'several': 199,
#  'brands': 200,
#  'around': 201,
#  'morning': 202,
#  'people': 203,
#  'absolutely': 204,
#  'bar': 205,
#  'amount': 206,
#  'smell': 207,
#  'fruit': 208,
#  'disappointed': 209,
#  'home': 210,
#  'away': 211,
#  'half': 212,
#  'fast': 213,
#  'wish': 214,
#  'cheese': 215,
#  'diet': 216,
#  'oz': 217,
#  'bitter': 218,
#  'added': 219,
#  'us': 220,
#  'usually': 221,
#  'foods': 222,
#  'able': 223,
#  'ones': 224,
#  'deal': 225,
#  'smooth': 226,
#  'available': 227,
#  'light': 228,
#  'fat': 229,
#  'dry': 230,
#  'days': 231,
#  'kind': 232,
#  'flavored': 233,
#  'case': 234,
#  'cats': 235,
#  'breakfast': 236,
#  'come': 237,
#  'ordering': 238,
#  'may': 239,
#  'works': 240,
#  'nothing': 241,
#  'per': 242,
#  'company': 243,
#  'save': 244,
#  'liked': 245,
#  'said': 246,
#  'probably': 247,
#  'problem': 248,
#  'seems': 249,
#  'black': 250,
#  'things': 251,
#  'peanut': 252,
#  'cheaper': 253,
#  'making': 254,
#  'boxes': 255,
#  'variety': 256,
#  'quick': 257,
#  'bread': 258,
#  'quickly': 259,
#  'fine': 260,
#  'especially': 261,
#  'packaging': 262,
#  'months': 263,
#  'bottle': 264,
#  'honey': 265,
#  'gift': 266,
#  'reviews': 267,
#  'glad': 268,
#  'others': 269,
#  'large': 270,
#  'rich': 271,
#  'recommended': 272,
#  'juice': 273,
#  'pasta': 274,
#  'gave': 275,
#  'son': 276,
#  'amazing': 277,
#  'comes': 278,
#  'drinking': 279,
#  'look': 280,
#  'instead': 281,
#  'protein': 282,
#  'spicy': 283,
#  'house': 284,
#  'prefer': 285,
#  'three': 286,
#  'thank': 287,
#  'thanks': 288,
#  'top': 289,
#  'times': 290,
#  'roast': 291,
#  'energy': 292,
#  'anyone': 293,
#  'syrup': 294,
#  'maybe': 295,
#  'yummy': 296,
#  'month': 297,
#  'likes': 298,
#  'vanilla': 299,
#  'meal': 300,
#  'white': 301,
#  'cream': 302,
#  'everyone': 303,
#  'daughter': 304,
#  'value': 305,
#  'pieces': 306,
#  'wanted': 307,
#  'must': 308,
#  'extra': 309,
#  'seem': 310,
#  'ginger': 311,
#  'teas': 312,
#  'fact': 313,
#  'cans': 314,
#  'baby': 315,
#  'teeth': 316,
#  'might': 317,
#  'soft': 318,
#  'next': 319,
#  'fan': 320,
#  'either': 321,
#  'enjoyed': 322,
#  'everything': 323,
#  'least': 324,
#  'stars': 325,
#  'health': 326,
#  'crunchy': 327,
#  'salty': 328,
#  'awesome': 329,
#  'else': 330,
#  'longer': 331,
#  'went': 332,
#  'bold': 333,
#  'cost': 334,
#  'nuts': 335,
#  'friends': 336,
#  'super': 337,
#  'plus': 338,
#  'couple': 339,
#  'keurig': 340,
#  'ago': 341,
#  'online': 342,
#  'yet': 343,
#  'market': 344,
#  'beans': 345,
#  'pleased': 346,
#  'ice': 347,
#  'plastic': 348,
#  'soup': 349,
#  'decided': 350,
#  'ok': 351,
#  'started': 352,
#  'chew': 353,
#  'noodles': 354,
#  'open': 355,
#  'help': 356,
#  'mouth': 357,
#  'flavorful': 358,
#  'took': 359,
#  'lemon': 360,
#  'minutes': 361,
#  'corn': 362,
#  'although': 363,
#  'cold': 364,
#  'rather': 365,
#  'expected': 366,
#  'second': 367,
#  'review': 368,
#  'service': 369,
#  'crackers': 370,
#  'alternative': 371,
#  'delivery': 372,
#  'week': 373,
#  'cocoa': 374,
#  'says': 375,
#  'snacks': 376,
#  'soda': 377,
#  'pepper': 378,
#  'wife': 379,
#  'goes': 380,
#  'let': 381,
#  'beef': 382,
#  'jerky': 383,
#  'cookie': 384,
#  'type': 385,
#  'french': 386,
#  'read': 387,
#  'meat': 388,
#  'decaf': 389,
#  'special': 390,
#  'weight': 391,
#  'cooking': 392,
#  'drinks': 393,
#  'machine': 394,
#  'exactly': 395,
#  'ounce': 396,
#  'fantastic': 397,
#  'opened': 398,
#  'gets': 399,
#  'powder': 400,
#  'wheat': 401,
#  'sometimes': 402,
#  'plain': 403,
#  'cook': 404,
#  'version': 405,
#  'believe': 406,
#  'surprised': 407,
#  'easily': 408,
#  'shipped': 409,
#  'packaged': 410,
#  'smaller': 411,
#  'mixed': 412,
#  'convenient': 413,
#  'aroma': 414,
#  'red': 415,
#  'side': 416,
#  'dried': 417,
#  'picky': 418,
#  'guess': 419,
#  'friend': 420,
#  'part': 421,
#  'problems': 422,
#  'orange': 423,
#  'subscribe': 424,
#  'aftertaste': 425,
#  'hand': 426,
#  'difference': 427,
#  'place': 428,
#  'giving': 429,
#  'coffees': 430,
#  'clean': 431,
#  'artificial': 432,
#  'smells': 433,
#  'refreshing': 434,
#  'recipe': 435,
#  'choice': 436,
#  'reason': 437,
#  'live': 438,
#  'oatmeal': 439,
#  'care': 440,
#  'cake': 441,
#  'seeds': 442,
#  'christmas': 443,
#  'packs': 444,
#  'wrong': 445,
#  'recently': 446,
#  'line': 447,
#  'cinnamon': 448,
#  'serving': 449,
#  'slightly': 450,
#  'chewy': 451,
#  'left': 452,
#  'tell': 453,
#  'continue': 454,
#  'mild': 455,
#  'iced': 456,
#  'pop': 457,
#  'container': 458,
#  'spice': 459,
#  'bulk': 460,
#  'bottles': 461,
#  'stomach': 462,
#  'gives': 463,
#  'almonds': 464,
#  'potato': 465,
#  'lots': 466,
#  'often': 467,
#  'etc': 468,
#  'brown': 469,
#  'cherry': 470,
#  'sent': 471,
#  'needed': 472,
#  'brew': 473,
#  'run': 474,
#  'chai': 475,
#  'bite': 476,
#  'delivered': 477,
#  'compared': 478,
#  'stick': 479,
#  'huge': 480,
#  'end': 481,
#  'looks': 482,
#  'starbucks': 483,
#  'packages': 484,
#  'fiber': 485,
#  'filling': 486,
#  'life': 487,
#  'calorie': 488,
#  'pay': 489,
#  'cut': 490,
#  'past': 491,
#  'excited': 492,
#  'simply': 493,
#  'start': 494,
#  'seller': 495,
#  'unfortunately': 496,
#  'dinner': 497,
#  'toy': 498,
#  'looked': 499,
#  'granola': 500,
#  'apple': 501,
#  'larger': 502,
#  'com': 503,
#  'night': 504,
#  'eaten': 505,
#  'items': 506,
#  'carry': 507,
#  'weeks': 508,
#  'chip': 509,
#  'purchasing': 510,
#  'overall': 511,
#  'close': 512,
#  'gum': 513,
#  'ate': 514,
#  'lunch': 515,
#  'broken': 516,
#  'similar': 517,
#  'hope': 518,
#  'original': 519,
#  'wait': 520,
#  'soon': 521,
#  'canned': 522,
#  'waste': 523,
#  'creamy': 524,
#  'date': 525,
#  'healthier': 526,
#  'seasoning': 527,
#  'extremely': 528,
#  'color': 529,
#  'weak': 530,
#  'takes': 531,
#  'idea': 532,
#  'four': 533,
#  'needs': 534,
#  'heat': 535,
#  'saw': 536,
#  'helps': 537,
#  'feed': 538,
#  'sold': 539,
#  'salad': 540,
#  'packed': 541,
#  'jar': 542,
#  'stale': 543,
#  'inside': 544,
#  'gone': 545,
#  'already': 546,
#  'stock': 547,
#  'finally': 548,
#  'someone': 549,
#  'star': 550,
#  'crunch': 551,
#  'course': 552,
#  'olive': 553,
#  'nut': 554,
#  'condition': 555,
#  'along': 556,
#  'keeps': 557,
#  'sweetness': 558,
#  'change': 559,
#  'single': 560,
#  'please': 561,
#  'pound': 562,
#  'soy': 563,
#  'shipment': 564,
#  'locally': 565,
#  'espresso': 566,
#  'fish': 567,
#  'given': 568,
#  'microwave': 569,
#  'expect': 570,
#  'medium': 571,
#  'baking': 572,
#  'hours': 573,
#  'yum': 574,
#  'consistency': 575,
#  'training': 576,
#  'non': 577,
#  'caffeine': 578,
#  'experience': 579,
#  'beat': 580,
#  'daily': 581,
#  'banana': 582,
#  'hit': 583,
#  'sour': 584,
#  'list': 585,
#  'mine': 586,
#  'certainly': 587,
#  'licorice': 588,
#  'cheap': 589,
#  'stop': 590,
#  'rest': 591,
#  'hooked': 592,
#  'leave': 593,
#  'greenies': 594,
#  'instant': 595,
#  'anywhere': 596,
#  'pet': 597,
#  'lb': 598,
#  'stopped': 599,
#  'name': 600,
#  'due': 601,
#  'thick': 602,
#  'reasonable': 603,
#  'difficult': 604,
#  'packets': 605,
#  'hair': 606,
#  'totally': 607,
#  'future': 608,
#  'break': 609,
#  'puppy': 610,
#  'leaves': 611,
#  'eats': 612,
#  'flour': 613,
#  'yogurt': 614,
#  'together': 615,
#  'bowl': 616,
#  'satisfying': 617,
#  'within': 618,
#  'pork': 619,
#  'maker': 620,
#  'formula': 621,
#  'adding': 622,
#  'chili': 623,
#  'pumpkin': 624,
#  'ground': 625,
#  'moist': 626,
#  'ingredient': 627,
#  'done': 628,
#  'substitute': 629,
#  'combination': 630,
#  'crazy': 631,
#  'worked': 632,
#  'throw': 633,
#  'chews': 634,
#  'sale': 635,
#  'entire': 636,
#  'fun': 637,
#  'vet': 638,
#  'bland': 639,
#  'anymore': 640,
#  'easier': 641,
#  'pure': 642,
#  'spices': 643,
#  'based': 644,
#  'recipes': 645,
#  'yes': 646,
#  'true': 647,
#  'satisfied': 648,
#  'sell': 649,
#  'shop': 650,
#  'wow': 651,
#  'perfectly': 652,
#  'summer': 653,
#  'pot': 654,
#  'simple': 655,
#  'batch': 656,
#  'completely': 657,
#  'finding': 658,
#  'almond': 659,
#  'decent': 660,
#  'carb': 661,
#  'opinion': 662,
#  'pricey': 663,
#  'pick': 664,
#  'baked': 665,
#  'become': 666,
#  'sodium': 667,
#  'kick': 668,
#  'okay': 669,
#  'grey': 670,
#  'area': 671,
#  'five': 672,
#  'mind': 673,
#  'favorites': 674,
#  'customer': 675,
#  'raw': 676,
#  'packet': 677,
#  'grain': 678,
#  'horrible': 679,
#  'mint': 680,
#  'later': 681,
#  'world': 682,
#  'hoping': 683,
#  'hint': 684,
#  'priced': 685,
#  'stay': 686,
#  'today': 687,
#  'none': 688,
#  'seemed': 689,
#  'maple': 690,
#  'truly': 691,
#  'finish': 692,
#  'dish': 693,
#  'twice': 694,
#  'bottom': 695,
#  'count': 696,
#  'addition': 697,
#  'expecting': 698,
#  'dont': 699,
#  'tiny': 700,
#  'mom': 701,
#  'blue': 702,
#  'option': 703,
#  'content': 704,
#  'awful': 705,
#  'newman': 706,
#  'piece': 707,
#  'mess': 708,
#  'discovered': 709,
#  'plan': 710,
#  'costco': 711,
#  'lower': 712,
#  'door': 713,
#  'forward': 714,
#  'cooked': 715,
#  'varieties': 716,
#  'thin': 717,
#  'six': 718,
#  'mixes': 719,
#  'contains': 720,
#  'hour': 721,
#  'prices': 722,
#  'strawberry': 723,
#  'particular': 724,
#  'pleasant': 725,
#  'pods': 726,
#  'terrible': 727,
#  'roasted': 728,
#  'normally': 729,
#  'noticed': 730,
#  'serve': 731,
#  'turned': 732,
#  'told': 733,
#  'description': 734,
#  'pancakes': 735,
#  'adds': 736,
#  'veggies': 737,
#  'supermarket': 738,
#  'acid': 739,
#  'remember': 740,
#  'normal': 741,
#  'body': 742,
#  'unless': 743,
#  'issues': 744,
#  'earl': 745,
#  'warm': 746,
#  'mountain': 747,
#  'sweetener': 748,
#  'label': 749,
#  'switch': 750,
#  'oh': 751,
#  'fit': 752,
#  'loose': 753,
#  'paid': 754,
#  'drinker': 755,
#  'unlike': 756,
#  'bones': 757,
#  'glass': 758,
#  'return': 759,
#  'ready': 760,
#  'touch': 761,
#  'thinking': 762,
#  'everyday': 763,
#  'vinegar': 764,
#  'stronger': 765,
#  'agree': 766,
#  'chocolates': 767,
#  'shake': 768,
#  'seen': 769,
#  'impressed': 770,
#  'bears': 771,
#  'homemade': 772,
#  'skin': 773,
#  'liquid': 774,
#  'garlic': 775,
#  'carrying': 776,
#  'individual': 777,
#  'contain': 778,
#  'salmon': 779,
#  'candies': 780,
#  'feeling': 781,
#  'felt': 782,
#  'anyway': 783,
#  'meals': 784,
#  'thrilled': 785,
#  'called': 786,
#  'subscription': 787,
#  'italian': 788,
#  'wrapped': 789,
#  'nicely': 790,
#  'ask': 791,
#  'beverage': 792,
#  'allergies': 793,
#  'shape': 794,
#  'pie': 795,
#  'convenience': 796,
#  'job': 797,
#  'taking': 798,
#  'changed': 799,
#  'point': 800,
#  'immediately': 801,
#  'otherwise': 802,
#  'chewing': 803,
#  'crisp': 804,
#  'sticks': 805,
#  'craving': 806,
#  'bring': 807,
#  'sick': 808,
#  'flavoring': 809,
#  'person': 810,
#  'set': 811,
#  'matter': 812,
#  'bbq': 813,
#  'overpowering': 814,
#  'sea': 815,
#  'office': 816,
#  'feeding': 817,
#  'hands': 818,
#  'lime': 819,
#  'gummy': 820,
#  'overly': 821,
#  'caramel': 822,
#  'except': 823,
#  'send': 824,
#  'ship': 825,
#  'party': 826,
#  'kitchen': 827,
#  'mostly': 828,
#  'peanuts': 829,
#  'check': 830,
#  'types': 831,
#  'reading': 832,
#  'benefits': 833,
#  'bigger': 834,
#  'breath': 835,
#  'style': 836,
#  'uses': 837,
#  'results': 838,
#  'bean': 839,
#  'afternoon': 840,
#  'supposed': 841,
#  'eggs': 842,
#  'supply': 843,
#  'plenty': 844,
#  'walmart': 845,
#  'nearly': 846,
#  'heavy': 847,
#  'dishes': 848,
#  'china': 849,
#  'raspberry': 850,
#  'children': 851,
#  'balance': 852,
#  'somewhat': 853,
#  'bake': 854,
#  'sealed': 855,
#  'call': 856,
#  'prepare': 857,
#  'complaint': 858,
#  'alot': 859,
#  'berry': 860,
#  'share': 861,
#  'stevia': 862,
#  'fairly': 863,
#  'carbs': 864,
#  'mango': 865,
#  'biscuits': 866,
#  'nutrition': 867,
#  'replacement': 868,
#  'source': 869,
#  'working': 870,
#  'crispy': 871,
#  'lover': 872,
#  'higher': 873,
#  'hate': 874,
#  'served': 875,
#  'near': 876,
#  'stuck': 877,
#  'worst': 878,
#  'sample': 879,
#  'kept': 880,
#  'perhaps': 881,
#  'kid': 882,
#  'running': 883,
#  'dressing': 884,
#  'plant': 885,
#  'sorry': 886,
#  'kinds': 887,
#  'coming': 888,
#  'gourmet': 889,
#  'quantity': 890,
#  'picture': 891,
#  'disappointing': 892,
#  'usual': 893,
#  'pizza': 894,
#  'brought': 895,
#  'weird': 896,
#  'alone': 897,
#  'unique': 898,
#  'trouble': 899,
#  'ended': 900,
#  'paying': 901,
#  'reviewer': 902,
#  'brewed': 903,
#  'tart': 904,
#  'addicted': 905,
#  'mother': 906,
#  'sitting': 907,
#  'pouch': 908,
#  'enjoys': 909,
#  'gf': 910,
#  'dented': 911,
#  'whatever': 912,
#  'issue': 913,
#  'notice': 914,
#  'fill': 915,
#  'short': 916,
#  'jelly': 917,
#  'vegetables': 918,
#  'reviewers': 919,
#  'expiration': 920,
#  'jars': 921,
#  'mustard': 922,
#  'heard': 923,
#  'sort': 924,
#  'birthday': 925,
#  'potatoes': 926,
#  'double': 927,
#  'pops': 928,
#  'pleasantly': 929,
#  'means': 930,
#  'selling': 931,
#  'helped': 932,
#  'website': 933,
#  'brewing': 934,
#  'standard': 935,
#  'threw': 936,
#  'knew': 937,
#  'beer': 938,
#  'grams': 939,
#  'chance': 940,
#  'beautiful': 941,
#  'lbs': 942,
#  'directions': 943,
#  'gotten': 944,
#  'busy': 945,
#  'sensitive': 946,
#  'pounds': 947,
#  'school': 948,
#  'sauces': 949,
#  'pour': 950,
#  'traditional': 951,
#  'blends': 952,
#  'number': 953,
#  'personally': 954,
#  'clear': 955,
#  'carbonated': 956,
#  'nasty': 957,
#  'wants': 958,
#  'restaurant': 959,
#  'bitterness': 960,
#  'bits': 961,
#  'portion': 962,
#  'lasts': 963,
#  'fridge': 964,
#  'whenever': 965,
#  'blood': 966,
#  'cashews': 967,
#  'outside': 968,
#  'cool': 969,
#  'soups': 970,
#  'covered': 971,
#  'cheddar': 972,
#  'dessert': 973,
#  'addictive': 974,
#  'cause': 975,
#  'fair': 976,
#  'eater': 977,
#  'note': 978,
#  'lab': 979,
#  'melted': 980,
#  'careful': 981,
#  'bodied': 982,
#  'air': 983,
#  'trip': 984,
#  'shelf': 985,
#  'tomato': 986,
#  'slight': 987,
#  'gummi': 988,
#  'suggest': 989,
#  'sized': 990,
#  'states': 991,
#  'upset': 992,
#  'across': 993,
#  'vegan': 994,
#  'nutritional': 995,
#  'tuna': 996,
#  'appreciate': 997,
#  'tend': 998,
#  'tired': 999,
#  'offer': 1000,
#  ...}

# %%
threshold = 7
total_cnt = len(src_tokenizer.word_index) # 단어의 수
rare_cnt = 0 # 등장 빈도수가 threshold보다 작은 단어의 개수를 카운트
total_freq = 0 # 훈련 데이터의 전체 단어 빈도수 총 합
rare_freq = 0 # 등장 빈도수가 threshold보다 작은 단어의 등장 빈도수의 총 합

# 단어와 빈도수의 쌍(pair)을 key와 value로 받는다.
for key, value in src_tokenizer.word_counts.items():
    total_freq = total_freq + value

    # 단어의 등장 빈도수가 threshold보다 작으면
    if(value < threshold):
        rare_cnt = rare_cnt + 1
        rare_freq = rare_freq + value

print('단어 집합(vocabulary)의 크기 :', total_cnt)
print('등장 빈도가 %s번 이하인 희귀 단어의 수: %s'%(threshold - 1, rare_cnt))
print('단어 집합에서 희귀 단어를 제외시킬 경우의 단어 집합의 크기 %s'%(total_cnt - rare_cnt))
print("단어 집합에서 희귀 단어의 비율:", (rare_cnt / total_cnt)*100)
print("전체 등장 빈도에서 희귀 단어 등장 빈도 비율:", (rare_freq / total_freq)*100)
# Out:
# 단어 집합(vocabulary)의 크기 : 32012
# 등장 빈도가 6번 이하인 희귀 단어의 수: 23802
# 단어 집합에서 희귀 단어를 제외시킬 경우의 단어 집합의 크기 8210
# 단어 집합에서 희귀 단어의 비율: 74.3533674871923
# 전체 등장 빈도에서 희귀 단어 등장 빈도 비율: 3.4076915566725563

# %%
src_vocab = 8000
src_tokenizer = Tokenizer(num_words=src_vocab) # 단어 집합의 크기를 8,000으로 제한
src_tokenizer.fit_on_texts(encoder_input_train) # 단어 집합 재생성

# %%
# 텍스트 시퀀스를 정수 시퀀스로 변환
encoder_input_train = src_tokenizer.texts_to_sequences(encoder_input_train) 
encoder_input_test = src_tokenizer.texts_to_sequences(encoder_input_test)

# 잘 진행되었는지 샘플 출력
print(encoder_input_train[:3])
# Out:
# [[1435, 6, 5088, 9, 1792, 2679, 877, 89, 1647, 2973, 305, 76, 278, 194, 562, 22, 212, 18, 181, 5253, 30, 385, 86, 9, 1039, 5088, 200], [1077, 300, 6451, 48, 300, 4097, 666, 94, 23, 23, 328, 1516, 152, 667, 216, 62, 2405, 622, 643, 737, 112, 2080, 33, 5473, 30, 105], [64, 5, 164, 1250, 22, 9, 79, 9, 4, 25, 140, 106, 2255, 78, 20, 537, 4, 226, 524, 21, 668, 27, 278, 17, 474]]

# %%
tar_tokenizer = Tokenizer()
tar_tokenizer.fit_on_texts(decoder_input_train)

# %%
threshold = 6
total_cnt = len(tar_tokenizer.word_index) # 단어의 수
rare_cnt = 0 # 등장 빈도수가 threshold보다 작은 단어의 개수를 카운트
total_freq = 0 # 훈련 데이터의 전체 단어 빈도수 총 합
rare_freq = 0 # 등장 빈도수가 threshold보다 작은 단어의 등장 빈도수의 총 합

# 단어와 빈도수의 쌍(pair)을 key와 value로 받는다.
for key, value in tar_tokenizer.word_counts.items():
    total_freq = total_freq + value

    # 단어의 등장 빈도수가 threshold보다 작으면
    if(value < threshold):
        rare_cnt = rare_cnt + 1
        rare_freq = rare_freq + value

print('단어 집합(vocabulary)의 크기 :', total_cnt)
print('등장 빈도가 %s번 이하인 희귀 단어의 수: %s'%(threshold - 1, rare_cnt))
print('단어 집합에서 희귀 단어를 제외시킬 경우의 단어 집합의 크기 %s'%(total_cnt - rare_cnt))
print("단어 집합에서 희귀 단어의 비율:", (rare_cnt / total_cnt)*100)
print("전체 등장 빈도에서 희귀 단어 등장 빈도 비율:", (rare_freq / total_freq)*100)
# Out:
# 단어 집합(vocabulary)의 크기 : 10444
# 등장 빈도가 5번 이하인 희귀 단어의 수: 8063
# 단어 집합에서 희귀 단어를 제외시킬 경우의 단어 집합의 크기 2381
# 단어 집합에서 희귀 단어의 비율: 77.20222137112216
# 전체 등장 빈도에서 희귀 단어 등장 빈도 비율: 5.860802703261844

# %%
tar_vocab = 2000
tar_tokenizer = Tokenizer(num_words=tar_vocab) 
tar_tokenizer.fit_on_texts(decoder_input_train)
tar_tokenizer.fit_on_texts(decoder_target_train)

# 텍스트 시퀀스를 정수 시퀀스로 변환
decoder_input_train = tar_tokenizer.texts_to_sequences(decoder_input_train) 
decoder_target_train = tar_tokenizer.texts_to_sequences(decoder_target_train)
decoder_input_test = tar_tokenizer.texts_to_sequences(decoder_input_test)
decoder_target_test = tar_tokenizer.texts_to_sequences(decoder_target_test)

# 잘 변환되었는지 확인
print('input')
print('input ',decoder_input_train[:5])
print('target')
print('decoder ',decoder_target_train[:5])
# Out:
# input
# input  [[1, 7, 185, 236, 44], [1, 130, 32, 320], [1, 29, 52, 43, 141, 1944], [1, 3, 19, 6, 358, 43, 747], [1, 3, 101]]
# target
# decoder  [[7, 185, 236, 44, 2], [130, 32, 320, 2], [29, 52, 43, 141, 1944, 2], [3, 19, 6, 358, 43, 747, 2], [3, 101, 2]]

# %%
drop_train = [index for index, sentence in enumerate(decoder_input_train) if len(sentence) == 1]
drop_test = [index for index, sentence in enumerate(decoder_input_test) if len(sentence) == 1]

print('삭제할 훈련 데이터의 개수 :', len(drop_train))
print('삭제할 테스트 데이터의 개수 :', len(drop_test))

encoder_input_train = [sentence for index, sentence in enumerate(encoder_input_train) if index not in drop_train]
decoder_input_train = [sentence for index, sentence in enumerate(decoder_input_train) if index not in drop_train]
decoder_target_train = [sentence for index, sentence in enumerate(decoder_target_train) if index not in drop_train]

encoder_input_test = [sentence for index, sentence in enumerate(encoder_input_test) if index not in drop_test]
decoder_input_test = [sentence for index, sentence in enumerate(decoder_input_test) if index not in drop_test]
decoder_target_test = [sentence for index, sentence in enumerate(decoder_target_test) if index not in drop_test]

print('훈련 데이터의 개수 :', len(encoder_input_train))
print('훈련 레이블의 개수 :', len(decoder_input_train))
print('테스트 데이터의 개수 :', len(encoder_input_test))
print('테스트 레이블의 개수 :', len(decoder_input_test))
# Out:
# 삭제할 훈련 데이터의 개수 : 1244
# 삭제할 테스트 데이터의 개수 : 357
# 훈련 데이터의 개수 : 51411
# 훈련 레이블의 개수 : 51411
# 테스트 데이터의 개수 : 12806
# 테스트 레이블의 개수 : 12806

# %%
encoder_input_train = pad_sequences(encoder_input_train, maxlen=text_max_len, padding='post')
encoder_input_test = pad_sequences(encoder_input_test, maxlen=text_max_len, padding='post')
decoder_input_train = pad_sequences(decoder_input_train, maxlen=summary_max_len, padding='post')
decoder_target_train = pad_sequences(decoder_target_train, maxlen=summary_max_len, padding='post')
decoder_input_test = pad_sequences(decoder_input_test, maxlen=summary_max_len, padding='post')
decoder_target_test = pad_sequences(decoder_target_test, maxlen=summary_max_len, padding='post')

# %%
from tensorflow.keras.layers import Input, LSTM, Embedding, Dense, Concatenate, TimeDistributed
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint


# 인코더 설계 시작
embedding_dim = 128
hidden_size = 256

# 인코더
encoder_inputs = Input(shape=(text_max_len,))

# 인코더의 임베딩 층
enc_emb = Embedding(src_vocab, embedding_dim)(encoder_inputs)

# 인코더의 LSTM 1
# encoder_lstm1 = LSTM(hidden_size, return_sequences=True, return_state=True ,dropout = 0.4, recurrent_dropout = 0.4)
encoder_lstm1 = LSTM(hidden_size, return_sequences=True, return_state=True ,dropout = 0.4)
encoder_output1, state_h1, state_c1 = encoder_lstm1(enc_emb)

# 인코더의 LSTM 2
# encoder_lstm2 = LSTM(hidden_size, return_sequences=True, return_state=True, dropout=0.4, recurrent_dropout=0.4)
encoder_lstm2 = LSTM(hidden_size, return_sequences=True, return_state=True, dropout=0.4)
encoder_output2, state_h2, state_c2 = encoder_lstm2(encoder_output1)

# 인코더의 LSTM 3
# encoder_lstm3 = LSTM(hidden_size, return_state=True, return_sequences=True, dropout=0.4, recurrent_dropout=0.4)
encoder_lstm3 = LSTM(hidden_size, return_state=True, return_sequences=True, dropout=0.4)
encoder_outputs, state_h, state_c= encoder_lstm3(encoder_output2)

# %%
# 디코더 설계
decoder_inputs = Input(shape=(None,))

# 디코더의 임베딩 층
dec_emb_layer = Embedding(tar_vocab, embedding_dim)
dec_emb = dec_emb_layer(decoder_inputs)

# 디코더의 LSTM
# decoder_lstm = LSTM(hidden_size, return_sequences=True, return_state=True, dropout=0.4, recurrent_dropout=0.2)
decoder_lstm = LSTM(hidden_size, return_sequences=True, return_state=True, dropout=0.4)
decoder_outputs, _, _ = decoder_lstm(dec_emb, initial_state=[state_h, state_c])

# %%
# 디코더의 출력층
decoder_softmax_layer = Dense(tar_vocab, activation='softmax')
decoder_softmax_outputs = decoder_softmax_layer(decoder_outputs) 

# 모델 정의
model = Model([encoder_inputs, decoder_inputs], decoder_softmax_outputs)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 50)]         0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 50, 128)      1024000     input_1[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     [(None, 50, 256), (N 394240      embedding[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, None)]       0
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   [(None, 50, 256), (N 525312      lstm[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, None, 128)    256000      input_2[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   [(None, 50, 256), (N 525312      lstm_1[0][0]
# __________________________________________________________________________________________________
# lstm_3 (LSTM)                   [(None, None, 256),  394240      embedding_1[0][0]
#                                                                  lstm_2[0][1]
#                                                                  lstm_2[0][2]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, None, 2000)   514000      lstm_3[0][0]
# ==================================================================================================
# Total params: 3,633,104
# Trainable params: 3,633,104
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.layers import AdditiveAttention

# 어텐션 층(어텐션 함수)
attn_layer = AdditiveAttention(name='attention_layer')

# 인코더와 디코더의 모든 time step의 hidden state를 어텐션 층에 전달하고 결과를 리턴
attn_out = attn_layer([decoder_outputs, encoder_outputs])


# 어텐션의 결과와 디코더의 hidden state들을 연결
decoder_concat_input = Concatenate(axis=-1, name='concat_layer')([decoder_outputs, attn_out])

# 디코더의 출력층
decoder_softmax_layer = Dense(tar_vocab, activation='softmax')
decoder_softmax_outputs = decoder_softmax_layer(decoder_concat_input)

# 모델 정의
model = Model([encoder_inputs, decoder_inputs], decoder_softmax_outputs)
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 50)]         0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 50, 128)      1024000     input_1[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     [(None, 50, 256), (N 394240      embedding[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, None)]       0
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   [(None, 50, 256), (N 525312      lstm[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, None, 128)    256000      input_2[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   [(None, 50, 256), (N 525312      lstm_1[0][0]
# __________________________________________________________________________________________________
# lstm_3 (LSTM)                   [(None, None, 256),  394240      embedding_1[0][0]
#                                                                  lstm_2[0][1]
#                                                                  lstm_2[0][2]
# __________________________________________________________________________________________________
# attention_layer (AdditiveAttent (None, None, 256)    256         lstm_3[0][0]
#                                                                  lstm_2[0][0]
# __________________________________________________________________________________________________
# concat_layer (Concatenate)      (None, None, 512)    0           lstm_3[0][0]
#                                                                  attention_layer[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, None, 2000)   1026000     concat_layer[0][0]
# ==================================================================================================
# Total params: 4,145,360
# Trainable params: 4,145,360
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy')
es = EarlyStopping(monitor='val_loss', patience=2, verbose=1)
history = model.fit(x=[encoder_input_train, decoder_input_train], y=decoder_target_train, \
          validation_data=([encoder_input_test, decoder_input_test], decoder_target_test), \
          batch_size=256, callbacks=[es], epochs=50)
# Out:
# Epoch 1/50
# 201/201 [==============================] - 39s 71ms/step - loss: 2.7017 - val_loss: 2.4377
# Epoch 2/50
# 201/201 [==============================] - 13s 66ms/step - loss: 2.3655 - val_loss: 2.2979
# Epoch 3/50
# 201/201 [==============================] - 13s 66ms/step - loss: 2.2205 - val_loss: 2.1624
# Epoch 4/50
# 201/201 [==============================] - 13s 67ms/step - loss: 2.1072 - val_loss: 2.0829
# Epoch 5/50
# 201/201 [==============================] - 14s 68ms/step - loss: 2.0247 - val_loss: 2.0275
# Epoch 6/50
# 201/201 [==============================] - 14s 69ms/step - loss: 1.9586 - val_loss: 1.9845
# Epoch 7/50
# 201/201 [==============================] - 14s 70ms/step - loss: 1.9042 - val_loss: 1.9548
# Epoch 8/50
# 201/201 [==============================] - 14s 69ms/step - loss: 1.8580 - val_loss: 1.9318
# Epoch 9/50
# 201/201 [==============================] - 14s 69ms/step - loss: 1.8169 - val_loss: 1.9163
# Epoch 10/50
# 201/201 [==============================] - 14s 69ms/step - loss: 1.7793 - val_loss: 1.8969
# Epoch 11/50
# 201/201 [==============================] - 14s 69ms/step - loss: 1.7448 - val_loss: 1.8890
# Epoch 12/50
# 201/201 [==============================] - 14s 69ms/step - loss: 1.7124 - val_loss: 1.8876
# Epoch 13/50
# 201/201 [==============================] - 14s 69ms/step - loss: 1.6821 - val_loss: 1.8719
# Epoch 14/50
# 201/201 [==============================] - 14s 69ms/step - loss: 1.6543 - val_loss: 1.8715
# Epoch 15/50
# 201/201 [==============================] - 14s 69ms/step - loss: 1.6268 - val_loss: 1.8663
# Epoch 16/50
# 201/201 [==============================] - 14s 69ms/step - loss: 1.6018 - val_loss: 1.8694
# Epoch 17/50
# 201/201 [==============================] - 14s 69ms/step - loss: 1.5770 - val_loss: 1.8632
# Epoch 18/50
# 201/201 [==============================] - 14s 69ms/step - loss: 1.5529 - val_loss: 1.8701
# Epoch 19/50
# 201/201 [==============================] - 14s 69ms/step - loss: 1.5297 - val_loss: 1.8717
# Epoch 00019: early stopping

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %% [markdown]
# #### Inference 모델 구현

# %%
src_index_to_word = src_tokenizer.index_word # 원문 단어 집합에서 정수 -> 단어를 얻음
tar_word_to_index = tar_tokenizer.word_index # 요약 단어 집합에서 단어 -> 정수를 얻음
tar_index_to_word = tar_tokenizer.index_word # 요약 단어 집합에서 정수 -> 단어를 얻음

# %%
# 인코더 설계
encoder_model = Model(inputs=encoder_inputs, outputs=[encoder_outputs, state_h, state_c])

# 이전 시점의 상태들을 저장하는 텐서
decoder_state_input_h = Input(shape=(hidden_size,))
decoder_state_input_c = Input(shape=(hidden_size,))

dec_emb2 = dec_emb_layer(decoder_inputs)

# 문장의 다음 단어를 예측하기 위해서 초기 상태(initial_state)를 이전 시점의 상태로 사용. 이는 뒤의 함수 decode_sequence()에 구현
# 훈련 과정에서와 달리 LSTM의 리턴하는 은닉 상태와 셀 상태인 state_h와 state_c를 버리지 않음.
decoder_outputs2, state_h2, state_c2 = decoder_lstm(dec_emb2, initial_state=[decoder_state_input_h, decoder_state_input_c])

# %%
# 어텐션 함수
decoder_hidden_state_input = Input(shape=(text_max_len, hidden_size))
attn_out_inf = attn_layer([decoder_outputs2, decoder_hidden_state_input])
decoder_inf_concat = Concatenate(axis=-1, name='concat')([decoder_outputs2, attn_out_inf])

# 디코더의 출력층
decoder_outputs2 = decoder_softmax_layer(decoder_inf_concat) 

# 최종 디코더 모델
decoder_model = Model(
    [decoder_inputs] + [decoder_hidden_state_input,decoder_state_input_h, decoder_state_input_c],
    [decoder_outputs2] + [state_h2, state_c2])

# %%
def decode_sequence(input_seq):
    # 입력으로부터 인코더의 상태를 얻음
    e_out, e_h, e_c = encoder_model.predict(input_seq)

     # <SOS>에 해당하는 토큰 생성
    target_seq = np.zeros((1,1))
    target_seq[0, 0] = tar_word_to_index['sostoken']

    stop_condition = False
    decoded_sentence = ''
    while not stop_condition: # stop_condition이 True가 될 때까지 루프 반복

        output_tokens, h, c = decoder_model.predict([target_seq] + [e_out, e_h, e_c])
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_token = tar_index_to_word[sampled_token_index]

        if (sampled_token!='eostoken'):
            decoded_sentence += ' '+sampled_token

        #  <eos>에 도달하거나 최대 길이를 넘으면 중단.
        if (sampled_token == 'eostoken'  or len(decoded_sentence.split()) >= (summary_max_len-1)):
            stop_condition = True

        # 길이가 1인 타겟 시퀀스를 업데이트
        target_seq = np.zeros((1,1))
        target_seq[0, 0] = sampled_token_index

        # 상태를 업데이트 합니다.
        e_h, e_c = h, c

    return decoded_sentence

# %%
# 원문의 정수 시퀀스를 텍스트 시퀀스로 변환
def seq2text(input_seq):
    temp=''
    for i in input_seq:
        if (i!=0):
            temp = temp + src_index_to_word[i]+' '
    return temp

# 요약문의 정수 시퀀스를 텍스트 시퀀스로 변환
def seq2summary(input_seq):
    temp=''
    for i in input_seq:
        if ((i!=0 and i!=tar_word_to_index['sostoken']) and i!=tar_word_to_index['eostoken']):
            temp = temp + tar_index_to_word[i] + ' '
    return temp

print('=3')
# Out:
# =3

# %%
for i in range(50, 100):
    print("원문 :", seq2text(encoder_input_test[i]))
    print("실제 요약 :", seq2summary(decoder_input_test[i]))
    print("예측 요약 :", decode_sequence(encoder_input_test[i].reshape(1, text_max_len)))
    print("\n")
# Out:
# 원문 : like brownie mix usually use low fat recipe also add chocolate chips something else otherwise ends little bit dry still buy case
# 실제 요약 : feel better brownie some health
# 예측 요약 :  not bad
#
#
# 원문 : read weight loss among benefits thought would try make sure know related tomato chili pepper normal berry taste like bit dried tomato sweet fruit easy lose weight taste like dried tomato make available food
# 실제 요약 : berries for weight loss
# 예측 요약 :  good but not great
#
#
# 원문 : looking pretty good canned chili since way lazy make consistantly tried several amazon list product easily favorite seems alot canned almost pasty consistency one actually distinguish meat beans spicy exactly hot means could actually hotter tastes works fine
# 실제 요약 : great chili
# 예측 요약 :  good but not great
#
#
# 원문 : great treat dog loved em small good training smelled pretty bad got salmon chicken offensive odor buy reason
# 실제 요약 : good for dogs bad for your
# 예측 요약 :  my dog loves these
#
#
# 원문 : coffee full body rich taste price far coffee cup use much plastic
# 실제 요약 : fog chaser coffee
# 예측 요약 :  good coffee
#
#
# 원문 : good make great gluten free dairy free snack always looking snacks like normal snack taste good one works great
# 실제 요약 : delish
# 예측 요약 :  great gluten free snack
#
#
# 원문 : cheddar popcorn amazon good bought directly store vacuum sealed bags keep popcorn fresh great price fast shipping highly recommend cheese popcorn lovers best tasted
# 실제 요약 : the real deal
# 예측 요약 :  great popcorn
#
#
# 원문 : probe en argentina se en internet en amazon mi amazon son
# 실제 요약 : altoids the best
# 예측 요약 :  not worth the money
#
#
# 원문 : excellent product healthy delicious great texture feel mouth goes perfectly hummus spreads
# 실제 요약 : delicious
# 예측 요약 :  great product
#
#
# 원문 : box stores begun drop inventory items variety available safeway cat needs stomach problems able find amazon quantity discount delivery fantastic cat heaven knows three month supply cupboard
# 실제 요약 : select cat food
# 예측 요약 :  cat food
#
#
# 원문 : dog trouble digesting much rawhide bully sticks bone choice economical buying store delivered quickly dog tail could stop arrived highly recommend
# 실제 요약 : happy dog
# 예측 요약 :  great product
#
#
# 원문 : two chi love rough rawhide ones ignore smooth ones bought two toys rings go could care less give ring toss chase chew wish sold pack rough rawhide
# 실제 요약 : babies love this
# 예측 요약 :  my dog loves it
#
#
# 원문 : getting tired washing little refillable baskets make second cup solutions get multiple baskets disposable type little better coffee fewer solids easy use says
# 실제 요약 : makes keurig more convenient
# 예측 요약 :  great espresso
#
#
# 원문 : cafe escapes best hot chocolate cups purchase product office price good shipping free
# 실제 요약 : flavorful
# 예측 요약 :  great taste
#
#
# 원문 : wanted something healthy low sugars high fiber think bars fit bill little dry people may find sweet enough totally fine concerned added sugars processed grains granola bars happy purchase surprised compact packaging made storing bars easier tiny kitchen
# 실제 요약 : good healthy snack
# 예측 요약 :  tasty and healthy
#
#
# 원문 : say oil everything reviews stated oil strong scent since love herbal smells like bother oil works great pre poo natural type hair negative mineral oil mineral oil coats hair prevents moisture getting
# 실제 요약 : it is purpose
# 예측 요약 :  good stuff
#
#
# 원문 : purchased low salt indeed low salt however many many chips bag literally dripping oil never encountered problem potato chip brands unappetizing wants oil never buy would recommend others
# 실제 요약 : in oil
# 예측 요약 :  salt
#
#
# 원문 : tried bottle new improved strong chemical sour taste little chocolate flavor bad bottle throw away
# 실제 요약 : sour
# 예측 요약 :  not bad
#
#
# 원문 : needed healthy cereal gives fiber fattening helps regular bran simply healthy necessary cereal every day
# 실제 요약 : cereal
# 예측 요약 :  great cereal
#
#
# 원문 : since ive purchased dog food noticed dogs coat shiny less fur fallen energy poop much
# 실제 요약 : superb dog food
# 예측 요약 :  good product
#
#
# 원문 : love company love products particular flavor combo work nice vinegar tang front jelly donut aroma sweetness downright odd nice idea sticking good old malt vinegar variety
# 실제 요약 : stick with the sea salt vinegar
# 예측 요약 :  not bad
#
#
# 원문 : good lot cheaper chocolates lot better
# 실제 요약 : good value
# 예측 요약 :  good
#
#
# 원문 : put dog stocking christmas pleased snack likes regular sweet potato fries thought package dog ones would make happy
# 실제 요약 : dog was pleased
# 예측 요약 :  great treat
#
#
# 원문 : big red created worst tasting beverage long history soda forever brain thought bubble gum butt juice probably going need therapy terrible experience drinking horrible concoction thanks recommending garbage
# 실제 요약 : terrible
# 예측 요약 :  not bad
#
#
# 원문 : sure whether working clean dogs teeth beg every morning two last long enough give good chewing work
# 실제 요약 : chews
# 예측 요약 :  great product
#
#
# 원문 : like product low calories produces smooth pb good quality follow instructions however tasty peanut butter especially commercial ones skippy etc way since fat happen like natural pb one tends resemble taste buy despite price
# 실제 요약 : good but not the real thing
# 예측 요약 :  good stuff
#
#
# 원문 : initially used mix williams sonoma good pricey decided give one try great nice light batter works great fillings given christmas gifts definitely ordering bad part amazon free shipping though
# 실제 요약 : great mix
# 예측 요약 :  great for cooking
#
#
# 원문 : milk thistle said good liver mellow pleasant flavor really enjoy drinking brand always good quality teas
# 실제 요약 : very pleasant flavor and good quality
# 예측 요약 :  nice tea
#
#
# 원문 : first time ordered next time tasty
# 실제 요약 : snack
# 예측 요약 :  good
#
#
# 원문 : say brand food cat eat tears bag chewing soon get pour plastic container also hair balls
# 실제 요약 : meow
# 예측 요약 :  cat food
#
#
# 원문 : favorite lindt chocolate bars use create molded chocolates gift giving chocolate chili flavor improves incredibly intense love chocolate
# 실제 요약 : delicious lindt chili chocolate
# 예측 요약 :  best chocolate ever
#
#
# 원문 : overall decent taste expected also expect coconut water concentrate read fine print better next time pure coconut water always better imho added sugar would really necessary pure coconut water concentrate
# 실제 요약 : disappointed
# 예측 요약 :  not bad
#
#
# 원문 : good right green food item three year old mouth however bit salty buy way cheaper asian food grocery
# 실제 요약 : good but
# 예측 요약 :  good but not great
#
#
# 원문 : flavor jolt blue changed due change corn syrup sugar back day still pretty much thing always still tasty still packs caffeine punch always tasty classic bottles could ask
# 실제 요약 : blue again at long last
# 예측 요약 :  not bad
#
#
# 원문 : bought product convenience take anywhere price great taste pretty bland definitely full eating taste expected try
# 실제 요약 : tastes ok
# 예측 요약 :  good but not great
#
#
# 원문 : tried many flavored coconut waters zico offers best tasting coconut water amount calories
# 실제 요약 : best coconut water
# 예측 요약 :  best coconut water ever
#
#
# 원문 : generally like items newman product lines always seem great decadent flavor surprised disappointing bar love dark chocolate given choice always choose milk chocolate found bar bitter almost burnt tasting texture exceptionally gritty fair dark chocolate going silky texture milk chocolate mean crumble mouth disappointing experience
# 실제 요약 : this bar
# 예측 요약 :  not bad
#
#
# 원문 : bought pen write letter cookies tip fine expected maybe personal preference try cake pops made candy melts pen stopped working worked since try another brand next time
# 실제 요약 : not what was expected
# 예측 요약 :  not bad
#
#
# 원문 : taste like pop refreshing mouth liked healthier pop great taste refreshing
# 실제 요약 : very good
# 예측 요약 :  sweet
#
#
# 원문 : dog especially comes taking supplements put puppy paste supplement easily great product
# 실제 요약 : kong puppy paste
# 예측 요약 :  great dog food
#
#
# 원문 : cautious cut small corner pepper set tongue see tasted like surprised hot expecting rather sweet would almost say cayenne peppers sweet taste though hot still go great chili stars taste great hot
# 실제 요약 : habanero are then these
# 예측 요약 :  not the best
#
#
# 원문 : bad tasting tea actually seem help appetite good value money
# 실제 요약 : tea
# 예측 요약 :  good tea
#
#
# 원문 : product expensive cheez products popular sell well cannot oz packages cost price pak please find another supplier besides item way hope find another supplier soon
# 실제 요약 : great product too
# 예측 요약 :  good product
#
#
# 원문 : love chips delicious hard eat one bag flavors allow taste favorite flavor cheese ones go ahead try delicious
# 실제 요약 : pop delicious
# 예측 요약 :  great chips
#
#
# 원문 : tastes great need sugar trying see pressure goes update later
# 실제 요약 : nice flavor without sugar
# 예측 요약 :  good stuff
#
#
# 원문 : haribo gummi candy gold bears pound medication take dry mouth little guys help product helps problem taste good also sugarfree diabetic
# 실제 요약 : bears that help
# 예측 요약 :  gummi bears
#
#
# 원문 : red berries cereal great crispy soggy still good low calories high flavor go box week order amazon fill extra bags cart grocery store easier
# 실제 요약 : berries
# 예측 요약 :  great product
#
#
# 원문 : love clever design keeps dogs busy quite perfect bored dogs cold december day
# 실제 요약 : perfect
# 예측 요약 :  dogs love em
#
#
# 원문 : got amazing product summer beauty box fell love since trying amazingly tasty snack quaker bought boxes need pick another recommend product anyone like loves anything banana nut
# 실제 요약 : simply delicious
# 예측 요약 :  great snack
#
#
# 원문 : cats love cat food loaded juicy gravy male cat needs keep getting urinary tract infection using canned cat food soupy gravy put water food give cats food drops high quality olive oil top male cat even goes trash bag lick lid provide dry food male cat tendency uti
# 실제 요약 : my cats love chicken flavor weruva
# 예측 요약 :  cat food

# %% [markdown]
# #### 추출적 요약

# %%
import requests
from summa.summarizer import summarize

# %%
text = requests.get('http://rare-technologies.com/the_matrix_synopsis.txt').text

# %%
print(text[:1500])
# Out:
# The screen is filled with green, cascading code which gives way to the title, The Matrix.
#
# A phone rings and text appears on the screen: "Call trans opt: received. 2-19-98 13:24:18 REC: Log>" As a conversation takes place between Trinity (Carrie-Anne Moss) and Cypher (Joe Pantoliano), two free humans, a table of random green numbers are being scanned and individual numbers selected, creating a series of digits not unlike an ordinary phone number, as if a code is being deciphered or a call is being traced.
#
# Trinity discusses some unknown person. Cypher taunts Trinity, suggesting she enjoys watching him. Trinity counters that "Morpheus (Laurence Fishburne) says he may be 'the One'," just as the sound of a number being selected alerts Trinity that someone may be tracing their call. She ends the call.
#
# Armed policemen move down a darkened, decrepit hallway in the Heart O' the City Hotel, their flashlight beam bouncing just ahead of them. They come to room 303, kick down the door and find a woman dressed in black, facing away from them. It's Trinity. She brings her hands up from the laptop she's working on at their command.
#
# Outside the hotel a car drives up and three agents appear in neatly pressed black suits. They are Agent Smith (Hugo Weaving), Agent Brown (Paul Goddard), and Agent Jones (Robert Taylor). Agent Smith and the presiding police lieutenant argue. Agent Smith admonishes the policeman that they were given specific orders to contact the agents first, for their

# %%
print('Summary:')
print(summarize(text, ratio=0.005))
# Out:
# Summary:
# Morpheus, Trinity, Neo, Apoc, Switch, Mouse and Cypher are jacked into the Matrix.
# Trinity brings the helicopter down to the floor that Morpheus is on and Neo opens fire on the three Agents.

# %%
print('Summary:')
print(summarize(text, ratio=0.005, split=True))
# Out:
# Summary:
# ['Morpheus, Trinity, Neo, Apoc, Switch, Mouse and Cypher are jacked into the Matrix.', 'Trinity brings the helicopter down to the floor that Morpheus is on and Neo opens fire on the three Agents.']

# %%
print('Summary:')
print(summarize(text, words=50))
# Out:
# Summary:
# Trinity takes Neo to Morpheus.
# Morpheus, Trinity, Neo, Apoc, Switch, Mouse and Cypher are jacked into the Matrix.
# Trinity brings the helicopter down to the floor that Morpheus is on and Neo opens fire on the three Agents.

# %% [markdown]
# # 뉴스기사 요약해보기

# %%
from importlib.metadata import version
import nltk
import tensorflow
import summa

# %%
import urllib.request
urllib.request.urlretrieve("https://raw.githubusercontent.com/sunnysai12345/News_Summary/master/news_summary_more.csv", filename="news_summary_more.csv")
data = pd.read_csv('news_summary_more.csv', encoding='iso-8859-1')

# %%
data.sample(10)
# Out:
#                                                headlines  \
# 91320  Stars may go to prayer meet as it's like fashi...
# 71238  Two arrested for beating up photographers over...
# 85682  Arjun Tendulkar spotted doing net practice at ...
# 15458  FB blocked users from sharing stories about it...
# 23083  Indian govt stopped Vijay Mallya from meeting ...
# 4009   One 'magarmach' down: Badal after Sajjan Kumar...
# 94753  Pak poll body bans social media, YouTube in it...
# 625    Meghna was in sanyaas, wanted to raise her chi...
# 41998  Drone nearly hits plane landing in NZ with 278...
# 11063  Gambhir criticises Azhar being allowed to ring...
#
#                                                     text
# 91320  Actor Rishi Kapoor has said that celebrities a...
# 71238  The police on Friday arrested two restaurant b...
# 85682  Former cricketer Sachin Tendulkar's son Arjun ...
# 15458  Facebook allegedly blocked users from sharing ...
# 23083  Fugitive Indian businessman Vijay Mallya's req...
# 4009   After former Congress leader Sajjan Kumar surr...
# 94753  The Election Commission of Pakistan (ECP) has ...
# 625    Veteran poet-lyricist Gulzar, while talking ab...
# 41998  New Zealand's national carrier has revealed th...
# 11063  Gautam Gambhir criticised BCCI, CoA and Cricke...

# %%
print('Text 열에서 중복을 배제한 유일한 샘플의 수 :', data['text'].nunique())
print('Headlines 열에서 중복을 배제한 유일한 샘플의 수 :', data['headlines'].nunique())
# Out:
# Text 열에서 중복을 배제한 유일한 샘플의 수 : 98360
# Headlines 열에서 중복을 배제한 유일한 샘플의 수 : 98280

# %%
# inplace=True 를 설정하면 DataFrame 타입 값을 return 하지 않고 data 내부를 직접적으로 바꿉니다
data.drop_duplicates(subset = ['text'], inplace=True)
print('전체 샘플수 :', (len(data)))
# Out:
# 전체 샘플수 : 98360

# %%
print(data.isnull().sum())
# Out:
# headlines    0
# text         0
# dtype: int64

# %%
contractions = {"ain't": "is not", "aren't": "are not","can't": "cannot", "'cause": "because", "could've": "could have", "couldn't": "could not",
                           "didn't": "did not",  "doesn't": "does not", "don't": "do not", "hadn't": "had not", "hasn't": "has not", "haven't": "have not",
                           "he'd": "he would","he'll": "he will", "he's": "he is", "how'd": "how did", "how'd'y": "how do you", "how'll": "how will", "how's": "how is",
                           "I'd": "I would", "I'd've": "I would have", "I'll": "I will", "I'll've": "I will have","I'm": "I am", "I've": "I have", "i'd": "i would",
                           "i'd've": "i would have", "i'll": "i will",  "i'll've": "i will have","i'm": "i am", "i've": "i have", "isn't": "is not", "it'd": "it would",
                           "it'd've": "it would have", "it'll": "it will", "it'll've": "it will have","it's": "it is", "let's": "let us", "ma'am": "madam",
                           "mayn't": "may not", "might've": "might have","mightn't": "might not","mightn't've": "might not have", "must've": "must have",
                           "mustn't": "must not", "mustn't've": "must not have", "needn't": "need not", "needn't've": "need not have","o'clock": "of the clock",
                           "oughtn't": "ought not", "oughtn't've": "ought not have", "shan't": "shall not", "sha'n't": "shall not", "shan't've": "shall not have",
                           "she'd": "she would", "she'd've": "she would have", "she'll": "she will", "she'll've": "she will have", "she's": "she is",
                           "should've": "should have", "shouldn't": "should not", "shouldn't've": "should not have", "so've": "so have","so's": "so as",
                           "this's": "this is","that'd": "that would", "that'd've": "that would have", "that's": "that is", "there'd": "there would",
                           "there'd've": "there would have", "there's": "there is", "here's": "here is","they'd": "they would", "they'd've": "they would have",
                           "they'll": "they will", "they'll've": "they will have", "they're": "they are", "they've": "they have", "to've": "to have",
                           "wasn't": "was not", "we'd": "we would", "we'd've": "we would have", "we'll": "we will", "we'll've": "we will have", "we're": "we are",
                           "we've": "we have", "weren't": "were not", "what'll": "what will", "what'll've": "what will have", "what're": "what are",
                           "what's": "what is", "what've": "what have", "when's": "when is", "when've": "when have", "where'd": "where did", "where's": "where is",
                           "where've": "where have", "who'll": "who will", "who'll've": "who will have", "who's": "who is", "who've": "who have",
                           "why's": "why is", "why've": "why have", "will've": "will have", "won't": "will not", "won't've": "will not have",
                           "would've": "would have", "wouldn't": "would not", "wouldn't've": "would not have", "y'all": "you all",
                           "y'all'd": "you all would","y'all'd've": "you all would have","y'all're": "you all are","y'all've": "you all have",
                           "you'd": "you would", "you'd've": "you would have", "you'll": "you will", "you'll've": "you will have",
                           "you're": "you are", "you've": "you have"}

print("정규화 사전의 수: ", len(contractions))
# Out:
# 정규화 사전의 수:  120

# %%
print('불용어 개수 :', len(stopwords.words('english') ))
print(stopwords.words('english'))
# Out:
# 불용어 개수 : 179
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
# 데이터 전처리 함수
def preprocess_sentence(sentence, remove_stopwords=True):
    sentence = sentence.lower() # 텍스트 소문자화
    sentence = BeautifulSoup(sentence, "lxml").text # <br />, <a href = ...> 등의 html 태그 제거
    sentence = re.sub(r'\([^)]*\)', '', sentence) # 괄호로 닫힌 문자열 (...) 제거 Ex) my husband (and myself!) for => my husband for
    sentence = re.sub('"','', sentence) # 쌍따옴표 " 제거
    sentence = ' '.join([contractions[t] if t in contractions else t for t in sentence.split(" ")]) # 약어 정규화
    sentence = re.sub(r"'s\b","", sentence) # 소유격 제거. Ex) roland's -> roland
    sentence = re.sub("[^a-zA-Z]", " ", sentence) # 영어 외 문자(숫자, 특수문자 등) 공백으로 변환
    sentence = re.sub('[m]{2,}', 'mm', sentence) # m이 3개 이상이면 2개로 변경. Ex) ummmmmmm yeah -> umm yeah
    
    # 불용어 제거 (Text)
    if remove_stopwords:
        tokens = ' '.join(word for word in sentence.split() if not word in stopwords.words('english') if len(word) > 1)
    # 불용어 미제거 (Summary)
    else:
        tokens = ' '.join(word for word in sentence.split() if len(word) > 1)
    return tokens

# %%
clean_text = []
# 전체 Text 데이터에 대한 전처리 : 10분 이상 시간이 걸릴 수 있습니다. 
for s in tqdm(data['text']):
    clean_text.append(preprocess_sentence(s))

# 전처리 후 출력
print("Text 전처리 후 결과: ", clean_text[:5])
# Out:
#   6%|▌         | 5841/98360 [00:29<07:53, 195.34it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_65/1973124159.py in <module>
#       2 # 전체 Text 데이터에 대한 전처리 : 10분 이상 시간이 걸릴 수 있습니다.
#       3 for s in tqdm(data['text']):
# ----> 4     clean_text.append(preprocess_sentence(s))
#       5
#       6 # 전처리 후 출력
#
# /tmp/ipykernel_65/966821911.py in preprocess_sentence(sentence, remove_stopwords)
#      12     # 불용어 제거 (Text)
#      13     if remove_stopwords:
# ---> 14         tokens = ' '.join(word for word in sentence.split() if not word in stopwords.words('english') if len(word) > 1)
#      15     # 불용어 미제거 (Summary)
#      16     else:
#
# /tmp/ipykernel_65/966821911.py in <genexpr>(.0)
#      12     # 불용어 제거 (Text)
#      13     if remove_stopwords:
# ---> 14         tokens = ' '.join(word for word in sentence.split() if not word in stopwords.words('english') if len(word) > 1)
#      15     # 불용어 미제거 (Summary)
#      16     else:
#
# /opt/conda/lib/python3.9/site-packages/nltk/corpus/reader/wordlist.py in words(self, fileids, ignore_lines_startswith)
#      19         return [
#      20             line
# ---> 21             for line in line_tokenize(self.raw(fileids))
#      22             if not line.startswith(ignore_lines_startswith)
#      23         ]
#
# /opt/conda/lib/python3.9/site-packages/nltk/tokenize/simple.py in line_tokenize(text, blanklines)
#     135
#     136 def line_tokenize(text, blanklines="discard"):
# --> 137     return LineTokenizer(blanklines).tokenize(text)
#
# /opt/conda/lib/python3.9/site-packages/nltk/tokenize/simple.py in tokenize(self, s)
#     114         # If requested, strip off blank lines.
#     115         if self._blanklines == "discard":
# --> 116             lines = [l for l in lines if l.rstrip()]
#     117         elif self._blanklines == "discard-eof":
#     118             if lines and not lines[-1].strip():
#
# /opt/conda/lib/python3.9/site-packages/nltk/tokenize/simple.py in <listcomp>(.0)
#     114         # If requested, strip off blank lines.
#     115         if self._blanklines == "discard":
# --> 116             lines = [l for l in lines if l.rstrip()]
#     117         elif self._blanklines == "discard-eof":
#     118             if lines and not lines[-1].strip():
#
# KeyboardInterrupt:

# %%
clean_summary = []
# 전체 Summary 데이터에 대한 전처리 : 5분 이상 시간이 걸릴 수 있습니다. 
for s in tqdm(data['headlines']):
    clean_summary.append(preprocess_sentence(s, False))

print("Summary 전처리 후 결과: ", clean_summary[:5])

# %%
data['text'] = clean_text
data['headlines'] = clean_summary

# 빈 값을 Null 값으로 변환
data.replace('', np.nan, inplace=True)

# %%
data.isnull().sum()

# %%
# 길이 분포 출력
import matplotlib.pyplot as plt

text_len = [len(s.split()) for s in data['text']]
summary_len = [len(s.split()) for s in data['headlines']]

print('텍스트의 최소 길이 : {}'.format(np.min(text_len)))
print('텍스트의 최대 길이 : {}'.format(np.max(text_len)))
print('텍스트의 평균 길이 : {}'.format(np.mean(text_len)))
print('요약의 최소 길이 : {}'.format(np.min(summary_len)))
print('요약의 최대 길이 : {}'.format(np.max(summary_len)))
print('요약의 평균 길이 : {}'.format(np.mean(summary_len)))

plt.subplot(1,2,1)
plt.boxplot(text_len)
plt.title('text')
plt.subplot(1,2,2)
plt.boxplot(summary_len)
plt.title('headlines')
plt.tight_layout()
plt.show()

plt.title('text')
plt.hist(text_len, bins = 40)
plt.xlabel('length of samples')
plt.ylabel('number of samples')
plt.show()

plt.title('headlines')
plt.hist(summary_len, bins = 40)
plt.xlabel('length of samples')
plt.ylabel('number of samples')
plt.show()

# %%
text_max_len = 60
summary_max_len = 16

# %%
def below_threshold_len(max_len, nested_list):
    cnt = 0
    for s in nested_list:
        if(len(s.split()) <= max_len):
            cnt = cnt + 1
    print('전체 샘플 중 길이가 %s 이하인 샘플의 비율: %s'%(max_len, (cnt / len(nested_list))))

# %%
below_threshold_len(text_max_len, data['text'])
below_threshold_len(summary_max_len,  data['headlines'])

# %%
data = data[data['text'].apply(lambda x: len(x.split()) <= text_max_len)]
data = data[data['headlines'].apply(lambda x: len(x.split()) <= summary_max_len)]
print('전체 샘플수 :', (len(data)))

# %%
# 요약 데이터에는 시작 토큰과 종료 토큰을 추가한다.
data['decoder_input'] = data['headlines'].apply(lambda x : 'sostoken '+ x)
data['decoder_target'] = data['headlines'].apply(lambda x : x + ' eostoken')
data.head()

# %%
encoder_input = np.array(data['text']) # 인코더의 입력
decoder_input = np.array(data['decoder_input']) # 디코더의 입력
decoder_target = np.array(data['decoder_target']) # 디코더의 레이블

# %%
indices = np.arange(encoder_input.shape[0])
np.random.shuffle(indices)
print(indices)
# Out:
# [32600 96301 90634 ... 88159 90901 97908]

# %%
encoder_input = encoder_input[indices]
decoder_input = decoder_input[indices]
decoder_target = decoder_target[indices]

# %%
n_of_val = int(len(encoder_input)*0.2)
print('테스트 데이터의 수 :', n_of_val)
# Out:
# 테스트 데이터의 수 : 19672

# %%
encoder_input_train = encoder_input[:-n_of_val]
decoder_input_train = decoder_input[:-n_of_val]
decoder_target_train = decoder_target[:-n_of_val]

encoder_input_test = encoder_input[-n_of_val:]
decoder_input_test = decoder_input[-n_of_val:]
decoder_target_test = decoder_target[-n_of_val:]

print('훈련 데이터의 개수 :', len(encoder_input_train))
print('훈련 레이블의 개수 :', len(decoder_input_train))
print('테스트 데이터의 개수 :', len(encoder_input_test))
print('테스트 레이블의 개수 :', len(decoder_input_test))
# Out:
# 훈련 데이터의 개수 : 78688
# 훈련 레이블의 개수 : 78688
# 테스트 데이터의 개수 : 19672
# 테스트 레이블의 개수 : 19672

# %%
src_tokenizer = Tokenizer() # 토크나이저 정의
src_tokenizer.fit_on_texts(encoder_input_train) # 입력된 데이터로부터 단어 집합 생성
src_tokenizer.word_index
# Out:
# {'said': 1,
#  'india': 2,
#  'year': 3,
#  'added': 4,
#  'us': 5,
#  'also': 6,
#  'first': 7,
#  'police': 8,
#  'government': 9,
#  'people': 10,
#  'indian': 11,
#  'old': 12,
#  'two': 13,
#  'film': 14,
#  'minister': 15,
#  'president': 16,
#  'one': 17,
#  'crore': 18,
#  'world': 19,
#  'court': 20,
#  'state': 21,
#  'would': 22,
#  'years': 23,
#  'reportedly': 24,
#  'new': 25,
#  'time': 26,
#  'former': 27,
#  'delhi': 28,
#  'last': 29,
#  'reports': 30,
#  'three': 31,
#  'company': 32,
#  'like': 33,
#  'earlier': 34,
#  'based': 35,
#  'congress': 36,
#  'bjp': 37,
#  'man': 38,
#  'country': 39,
#  'team': 40,
#  'claimed': 41,
#  'accused': 42,
#  'pakistan': 43,
#  'singh': 44,
#  'day': 45,
#  'modi': 46,
#  'chief': 47,
#  'trump': 48,
#  'pm': 49,
#  'actor': 50,
#  'women': 51,
#  'million': 52,
#  'allegedly': 53,
#  'according': 54,
#  'made': 55,
#  'wednesday': 56,
#  'party': 57,
#  'friday': 58,
#  'pradesh': 59,
#  'monday': 60,
#  'tuesday': 61,
#  'comes': 62,
#  'called': 63,
#  'woman': 64,
#  'lakh': 65,
#  'video': 66,
#  'around': 67,
#  'asked': 68,
#  'thursday': 69,
#  'khan': 70,
#  'test': 71,
#  'billion': 72,
#  'tweeted': 73,
#  'took': 74,
#  'cm': 75,
#  'including': 76,
#  'mumbai': 77,
#  'case': 78,
#  'actress': 79,
#  'could': 80,
#  'found': 81,
#  'revealed': 82,
#  'four': 83,
#  'national': 84,
#  'arrested': 85,
#  'saturday': 86,
#  'leader': 87,
#  'sunday': 88,
#  'officials': 89,
#  'five': 90,
#  'wrote': 91,
#  'match': 92,
#  'second': 93,
#  'announced': 94,
#  'group': 95,
#  'high': 96,
#  'following': 97,
#  'used': 98,
#  'however': 99,
#  'captain': 100,
#  'startup': 101,
#  'since': 102,
#  'take': 103,
#  'china': 104,
#  'users': 105,
#  'alleged': 106,
#  'notably': 107,
#  'part': 108,
#  'due': 109,
#  'media': 110,
#  'narendra': 111,
#  'bank': 112,
#  'family': 113,
#  'cricket': 114,
#  'killed': 115,
#  'may': 116,
#  'get': 117,
#  'make': 118,
#  'th': 119,
#  'international': 120,
#  'ceo': 121,
#  'led': 122,
#  'adding': 123,
#  'days': 124,
#  'security': 125,
#  'per': 126,
#  'set': 127,
#  'six': 128,
#  'donald': 129,
#  'gandhi': 130,
#  'month': 131,
#  'air': 132,
#  'facebook': 133,
#  'twitter': 134,
#  'south': 135,
#  'home': 136,
#  'house': 137,
#  'life': 138,
#  'kapoor': 139,
#  'saying': 140,
#  'work': 141,
#  'data': 142,
#  'report': 143,
#  'help': 144,
#  'number': 145,
#  'series': 146,
#  'north': 147,
#  'another': 148,
#  'incident': 149,
#  'prime': 150,
#  'picture': 151,
#  'using': 152,
#  'social': 153,
#  'official': 154,
#  'later': 155,
#  'several': 156,
#  'car': 157,
#  'girl': 158,
#  'kumar': 159,
#  'board': 160,
#  'seen': 161,
#  'wife': 162,
#  'back': 163,
#  'uttar': 164,
#  'show': 165,
#  'next': 166,
#  'supreme': 167,
#  'week': 168,
#  'money': 169,
#  'australia': 170,
#  'public': 171,
#  'released': 172,
#  'elections': 173,
#  'talking': 174,
#  'rahul': 175,
#  'union': 176,
#  'post': 177,
#  'upcoming': 178,
#  'students': 179,
#  'city': 180,
#  'least': 181,
#  'among': 182,
#  'google': 183,
#  'hospital': 184,
#  'death': 185,
#  'filed': 186,
#  'third': 187,
#  'launched': 188,
#  'school': 189,
#  'become': 190,
#  'without': 191,
#  'recently': 192,
#  'taken': 193,
#  'user': 194,
#  'months': 195,
#  'nearly': 196,
#  'kohli': 197,
#  'got': 198,
#  'even': 199,
#  'men': 200,
#  'record': 201,
#  'shared': 202,
#  'children': 203,
#  'director': 204,
#  'technology': 205,
#  'cup': 206,
#  'son': 207,
#  'run': 208,
#  'centre': 209,
#  'many': 210,
#  'times': 211,
#  'uk': 212,
#  'others': 213,
#  'worth': 214,
#  'named': 215,
#  'online': 216,
#  'co': 217,
#  'attack': 218,
#  'win': 219,
#  'ever': 220,
#  'release': 221,
#  'away': 222,
#  'held': 223,
#  'came': 224,
#  'deal': 225,
#  'place': 226,
#  'father': 227,
#  'ministry': 228,
#  'district': 229,
#  'researchers': 230,
#  'shah': 231,
#  'korea': 232,
#  'making': 233,
#  'hit': 234,
#  'cannot': 235,
#  'use': 236,
#  'law': 237,
#  'order': 238,
#  'sharma': 239,
#  'long': 240,
#  'told': 241,
#  'final': 242,
#  'across': 243,
#  'open': 244,
#  'given': 245,
#  'reported': 246,
#  'system': 247,
#  'england': 248,
#  'body': 249,
#  'directed': 250,
#  'founder': 251,
#  'died': 252,
#  'water': 253,
#  'members': 254,
#  'working': 255,
#  'event': 256,
#  'along': 257,
#  'daughter': 258,
#  'general': 259,
#  'started': 260,
#  'capital': 261,
#  'army': 262,
#  'app': 263,
#  'taking': 264,
#  'come': 265,
#  'received': 266,
#  'every': 267,
#  'karnataka': 268,
#  'pay': 269,
#  'tax': 270,
#  'american': 271,
#  'assembly': 272,
#  'way': 273,
#  'person': 274,
#  'firm': 275,
#  'runs': 276,
#  'apple': 277,
#  'hours': 278,
#  'top': 279,
#  'department': 280,
#  'want': 281,
#  'decision': 282,
#  'flight': 283,
#  'best': 284,
#  'united': 285,
#  'lost': 286,
#  'go': 287,
#  'play': 288,
#  'chinese': 289,
#  'left': 290,
#  'mother': 291,
#  'space': 292,
#  'raised': 293,
#  'largest': 294,
#  'university': 295,
#  'never': 296,
#  'officer': 297,
#  'today': 298,
#  'kashmir': 299,
#  'services': 300,
#  'within': 301,
#  'went': 302,
#  'fire': 303,
#  'end': 304,
#  'seven': 305,
#  'human': 306,
#  'star': 307,
#  'right': 308,
#  'highest': 309,
#  'states': 310,
#  'cricketer': 311,
#  'player': 312,
#  'became': 313,
#  'chairman': 314,
#  'employees': 315,
#  'injured': 316,
#  'kerala': 317,
#  'name': 318,
#  'speaking': 319,
#  'australian': 320,
#  'read': 321,
#  'good': 322,
#  'service': 323,
#  'power': 324,
#  'authorities': 325,
#  'well': 326,
#  'films': 327,
#  'odi': 328,
#  'playing': 329,
#  'known': 330,
#  'ram': 331,
#  'food': 332,
#  'issued': 333,
#  'business': 334,
#  'airport': 335,
#  'russia': 336,
#  'bengaluru': 337,
#  'gold': 338,
#  'countries': 339,
#  'meeting': 340,
#  'action': 341,
#  'league': 342,
#  'sent': 343,
#  'companies': 344,
#  'total': 345,
#  'give': 346,
#  'sexual': 347,
#  'december': 348,
#  'support': 349,
#  'information': 350,
#  'maharashtra': 351,
#  'meanwhile': 352,
#  'role': 353,
#  'private': 354,
#  'eight': 355,
#  'russian': 356,
#  'move': 357,
#  'posted': 358,
#  'central': 359,
#  'currently': 360,
#  'foreign': 361,
#  'round': 362,
#  'office': 363,
#  'gujarat': 364,
#  'march': 365,
#  'free': 366,
#  'face': 367,
#  'head': 368,
#  'cases': 369,
#  'june': 370,
#  'near': 371,
#  'virat': 372,
#  'tweet': 373,
#  'amid': 374,
#  'election': 375,
#  'slammed': 376,
#  'special': 377,
#  'instagram': 378,
#  'share': 379,
#  'visit': 380,
#  'issue': 381,
#  'ahead': 382,
#  'tamil': 383,
#  'ball': 384,
#  'child': 385,
#  'list': 386,
#  'war': 387,
#  'market': 388,
#  'commission': 389,
#  'sabha': 390,
#  'song': 391,
#  'love': 392,
#  'going': 393,
#  'claiming': 394,
#  'investigation': 395,
#  'statement': 396,
#  'scored': 397,
#  'un': 398,
#  'scheduled': 399,
#  'need': 400,
#  'ex': 401,
#  'think': 402,
#  'much': 403,
#  'ban': 404,
#  'salman': 405,
#  'bihar': 406,
#  'registered': 407,
#  'know': 408,
#  'january': 409,
#  'husband': 410,
#  'ipl': 411,
#  'non': 412,
#  'nuclear': 413,
#  'senior': 414,
#  'sri': 415,
#  'passengers': 416,
#  'played': 417,
#  'health': 418,
#  'april': 419,
#  'development': 420,
#  'august': 421,
#  'anti': 422,
#  'ago': 423,
#  'september': 424,
#  'class': 425,
#  'boy': 426,
#  'singer': 427,
#  'secretary': 428,
#  'west': 429,
#  'global': 430,
#  'real': 431,
#  'punjab': 432,
#  'shot': 433,
#  'leaders': 434,
#  'platform': 435,
#  'uber': 436,
#  'shows': 437,
#  'defence': 438,
#  'feature': 439,
#  'military': 440,
#  'inside': 441,
#  'train': 442,
#  'funding': 443,
#  'pakistani': 444,
#  'finance': 445,
#  'see': 446,
#  'recent': 447,
#  'launch': 448,
#  'passed': 449,
#  'put': 450,
#  'rape': 451,
#  'political': 452,
#  'news': 453,
#  'late': 454,
#  'age': 455,
#  'wedding': 456,
#  'major': 457,
#  'yadav': 458,
#  'players': 459,
#  'student': 460,
#  'failed': 461,
#  'trying': 462,
#  'female': 463,
#  'mp': 464,
#  'allegations': 465,
#  'dead': 466,
#  'denied': 467,
#  'act': 468,
#  'ordered': 469,
#  'giant': 470,
#  'station': 471,
#  'cbi': 472,
#  'different': 473,
#  'complaint': 474,
#  'financial': 475,
#  'suicide': 476,
#  'towards': 477,
#  'side': 478,
#  'area': 479,
#  'member': 480,
#  'bollywood': 481,
#  'force': 482,
#  'still': 483,
#  'project': 484,
#  'wanted': 485,
#  'november': 486,
#  'bill': 487,
#  'couple': 488,
#  'lead': 489,
#  'stop': 490,
#  'medical': 491,
#  'game': 492,
#  'jail': 493,
#  'july': 494,
#  'phone': 495,
#  'amazon': 496,
#  'minutes': 497,
#  'dhoni': 498,
#  'study': 499,
#  'building': 500,
#  'decided': 501,
#  'october': 502,
#  'getting': 503,
#  'change': 504,
#  'stated': 505,
#  'korean': 506,
#  'history': 507,
#  'nadu': 508,
#  'earth': 509,
#  'paid': 510,
#  'victim': 511,
#  'award': 512,
#  'white': 513,
#  'claims': 514,
#  'expected': 515,
#  'fake': 516,
#  'past': 517,
#  'outside': 518,
#  'look': 519,
#  'plans': 520,
#  'agency': 521,
#  'road': 522,
#  'allowed': 523,
#  'british': 524,
#  'local': 525,
#  'account': 526,
#  'forces': 527,
#  'vice': 528,
#  'married': 529,
#  'founded': 530,
#  'reacting': 531,
#  'birthday': 532,
#  'priyanka': 533,
#  'committee': 534,
#  'mark': 535,
#  'sachin': 536,
#  'calling': 537,
#  'rajasthan': 538,
#  'games': 539,
#  'musk': 540,
#  'saudi': 541,
#  'together': 542,
#  'debut': 543,
#  'driver': 544,
#  'iran': 545,
#  'scientists': 546,
#  'railway': 547,
#  'control': 548,
#  'temple': 549,
#  'ali': 550,
#  'despite': 551,
#  'football': 552,
#  'workers': 553,
#  'jammu': 554,
#  'batsman': 555,
#  'campaign': 556,
#  'seeking': 557,
#  'great': 558,
#  'quarter': 559,
#  'winning': 560,
#  'rights': 561,
#  'refused': 562,
#  'letter': 563,
#  'cost': 564,
#  'sharing': 565,
#  'gst': 566,
#  'behind': 567,
#  'live': 568,
#  'till': 569,
#  'madhya': 570,
#  'nation': 571,
#  'starrer': 572,
#  'half': 573,
#  'big': 574,
#  'always': 575,
#  'violence': 576,
#  'parents': 577,
#  'coach': 578,
#  'planning': 579,
#  'provide': 580,
#  'tesla': 581,
#  'black': 582,
#  'mobile': 583,
#  'nine': 584,
#  'developed': 585,
#  'fell': 586,
#  'border': 587,
#  'pictures': 588,
#  'africa': 589,
#  'nasa': 590,
#  'london': 591,
#  'night': 592,
#  'gave': 593,
#  'personal': 594,
#  'parliament': 595,
#  'banned': 596,
#  'single': 597,
#  'affairs': 598,
#  'instead': 599,
#  'fourth': 600,
#  'call': 601,
#  'haryana': 602,
#  'met': 603,
#  'land': 604,
#  'protest': 605,
#  'filmmaker': 606,
#  'lok': 607,
#  'fund': 608,
#  'biggest': 609,
#  'murder': 610,
#  'leave': 611,
#  'season': 612,
#  'justice': 613,
#  'innings': 614,
#  'amount': 615,
#  'club': 616,
#  'declared': 617,
#  'previous': 618,
#  'matches': 619,
#  'french': 620,
#  'matter': 621,
#  'offered': 622,
#  'industry': 623,
#  'intelligence': 624,
#  'career': 625,
#  'muslim': 626,
#  'brother': 627,
#  'far': 628,
#  'start': 629,
#  'loss': 630,
#  'aircraft': 631,
#  'tournament': 632,
#  'light': 633,
#  'cash': 634,
#  'turned': 635,
#  'better': 636,
#  'flipkart': 637,
#  'happy': 638,
#  'stating': 639,
#  'self': 640,
#  'tried': 641,
#  'staff': 642,
#  'showed': 643,
#  'spokesperson': 644,
#  'price': 645,
#  'confirmed': 646,
#  'able': 647,
#  'must': 648,
#  'return': 649,
#  'probe': 650,
#  'model': 651,
#  'bachchan': 652,
#  'yet': 653,
#  'opposition': 654,
#  'harassment': 655,
#  'already': 656,
#  'aadhaar': 657,
#  'education': 658,
#  'suspended': 659,
#  'sale': 660,
#  'level': 661,
#  'bengal': 662,
#  'hotel': 663,
#  'investors': 664,
#  'created': 665,
#  'charges': 666,
#  'written': 667,
#  'let': 668,
#  'current': 669,
#  'banks': 670,
#  'indians': 671,
#  'vehicles': 672,
#  'girls': 673,
#  'chopra': 674,
#  'say': 675,
#  'farmers': 676,
#  'cut': 677,
#  'issues': 678,
#  'baby': 679,
#  'km': 680,
#  'create': 681,
#  'shares': 682,
#  'stake': 683,
#  'driving': 684,
#  'hyderabad': 685,
#  'rukh': 686,
#  'period': 687,
#  'champions': 688,
#  'appointed': 689,
#  'february': 690,
#  'admitted': 691,
#  'character': 692,
#  'missing': 693,
#  'allow': 694,
#  'increase': 695,
#  'organisation': 696,
#  'japan': 697,
#  'investment': 698,
#  'income': 699,
#  'tv': 700,
#  'reliance': 701,
#  'include': 702,
#  'oil': 703,
#  'done': 704,
#  'mla': 705,
#  'caused': 706,
#  'hand': 707,
#  'village': 708,
#  'nations': 709,
#  'owned': 710,
#  'job': 711,
#  'operations': 712,
#  'showing': 713,
#  'officers': 714,
#  'lanka': 715,
#  'wearing': 716,
#  'fight': 717,
#  'wickets': 718,
#  'vehicle': 719,
#  'meet': 720,
#  'carrying': 721,
#  'proposed': 722,
#  'customers': 723,
#  'full': 724,
#  'rbi': 725,
#  'gone': 726,
#  'keep': 727,
#  'ongoing': 728,
#  'sanjay': 729,
#  'sold': 730,
#  'involved': 731,
#  'accounts': 732,
#  'form': 733,
#  'demanded': 734,
#  'score': 735,
#  'warned': 736,
#  'photo': 737,
#  'policy': 738,
#  'marriage': 739,
#  'plan': 740,
#  'reach': 741,
#  'afghanistan': 742,
#  'economic': 743,
#  'sought': 744,
#  'less': 745,
#  'bus': 746,
#  'commerce': 747,
#  'suggested': 748,
#  'term': 749,
#  'things': 750,
#  'attacks': 751,
#  'continue': 752,
#  'process': 753,
#  'rao': 754,
#  'region': 755,
#  'personnel': 756,
#  'adityanath': 757,
#  'lot': 758,
#  'reached': 759,
#  'defeated': 760,
#  'hindu': 761,
#  'broke': 762,
#  'trade': 763,
#  'treatment': 764,
#  'caught': 765,
#  'talks': 766,
#  'giving': 767,
#  'passenger': 768,
#  'committed': 769,
#  'sex': 770,
#  'governor': 771,
#  'response': 772,
#  'forced': 773,
#  'various': 774,
#  'community': 775,
#  'features': 776,
#  'seats': 777,
#  'room': 778,
#  'cars': 779,
#  'asking': 780,
#  'karan': 781,
#  'illegal': 782,
#  'research': 783,
#  'ensure': 784,
#  'addressing': 785,
#  'hearing': 786,
#  'red': 787,
#  'friend': 788,
#  'deepika': 789,
#  'council': 790,
#  'related': 791,
#  'yogi': 792,
#  'terror': 793,
#  'title': 794,
#  'products': 795,
#  'access': 796,
#  'corporation': 797,
#  'spot': 798,
#  'story': 799,
#  'feel': 800,
#  'threatened': 801,
#  'ranveer': 802,
#  'future': 803,
#  'airline': 804,
#  'notice': 805,
#  'almost': 806,
#  'friends': 807,
#  'date': 808,
#  'compared': 809,
#  'signed': 810,
#  'find': 811,
#  'forward': 812,
#  'jaitley': 813,
#  'looking': 814,
#  'doctors': 815,
#  'ended': 816,
#  'value': 817,
#  'revenue': 818,
#  'electric': 819,
#  'andhra': 820,
#  'born': 821,
#  'television': 822,
#  'offer': 823,
#  'vijay': 824,
#  'saw': 825,
#  'discovered': 826,
#  'zealand': 827,
#  'travel': 828,
#  'fans': 829,
#  'whatsapp': 830,
#  'anil': 831,
#  'viral': 832,
#  'increased': 833,
#  'york': 834,
#  'hour': 835,
#  'built': 836,
#  'safety': 837,
#  'whose': 838,
#  'legal': 839,
#  'someone': 840,
#  'deputy': 841,
#  'bcci': 842,
#  'line': 843,
#  'birth': 844,
#  'judge': 845,
#  'stars': 846,
#  'kejriwal': 847,
#  'protests': 848,
#  'pacer': 849,
#  'victory': 850,
#  'soon': 851,
#  'management': 852,
#  'music': 853,
#  'corruption': 854,
#  'festival': 855,
#  'really': 856,
#  'dismissed': 857,
#  'net': 858,
#  'bangladesh': 859,
#  'internet': 860,
#  'actors': 861,
#  'traffic': 862,
#  'areas': 863,
#  'agreed': 864,
#  'aged': 865,
#  'schools': 866,
#  'ceremony': 867,
#  'english': 868,
#  'killing': 869,
#  'points': 870,
#  'hai': 871,
#  'goal': 872,
#  'rejected': 873,
#  'sena': 874,
#  'al': 875,
#  'german': 876,
#  'kg': 877,
#  'strike': 878,
#  'delivery': 879,
#  'conducted': 880,
#  'close': 881,
#  'akshay': 882,
#  'low': 883,
#  'cover': 884,
#  'front': 885,
#  'suffered': 886,
#  'medal': 887,
#  'tendulkar': 888,
#  'parties': 889,
#  'fine': 890,
#  'wants': 891,
#  'removed': 892,
#  'arrest': 893,
#  'asian': 894,
#  'imposed': 895,
#  'college': 896,
#  'helped': 897,
#  'affected': 898,
#  'weeks': 899,
#  'leading': 900,
#  'elon': 901,
#  'jobs': 902,
#  'production': 903,
#  'similar': 904,
#  'ground': 905,
#  'digital': 906,
#  'ambani': 907,
#  'airlines': 908,
#  'citizens': 909,
#  'trophy': 910,
#  'metro': 911,
#  'available': 912,
#  'emergency': 913,
#  'kolkata': 914,
#  'small': 915,
#  'accident': 916,
#  'wrong': 917,
#  'rohit': 918,
#  'website': 919,
#  'began': 920,
#  'approved': 921,
#  'administration': 922,
#  'whether': 923,
#  'germany': 924,
#  'claim': 925,
#  'islamic': 926,
#  'search': 927,
#  'charge': 928,
#  'ms': 929,
#  'joined': 930,
#  'kangana': 931,
#  'spinner': 932,
#  'aap': 933,
#  'aimed': 934,
#  'anyone': 935,
#  'growth': 936,
#  'amit': 937,
#  'interview': 938,
#  'surfaced': 939,
#  'militants': 940,
#  'site': 941,
#  'brought': 942,
#  'book': 943,
#  'chennai': 944,
#  'position': 945,
#  'prasad': 946,
#  'worked': 947,
#  'kapil': 948,
#  'opened': 949,
#  'shooting': 950,
#  'scheme': 951,
#  'association': 952,
#  'france': 953,
#  'owner': 954,
#  'followed': 955,
#  'rate': 956,
#  'details': 957,
#  'feet': 958,
#  'grand': 959,
#  'executive': 960,
#  'iphone': 961,
#  'asia': 962,
#  'urged': 963,
#  'early': 964,
#  'buy': 965,
#  'relationship': 966,
#  'message': 967,
#  'injuries': 968,
#  'network': 969,
#  'connection': 970,
#  'funds': 971,
#  'included': 972,
#  'fashion': 973,
#  'sector': 974,
#  'victims': 975,
#  'brand': 976,
#  'programme': 977,
#  'kim': 978,
#  'attacked': 979,
#  'mission': 980,
#  'training': 981,
#  'tata': 982,
#  'served': 983,
#  'build': 984,
#  'joint': 985,
#  'device': 986,
#  'annual': 987,
#  'missile': 988,
#  'crime': 989,
#  'de': 990,
#  'charged': 991,
#  'journalist': 992,
#  'rules': 993,
#  'peace': 994,
#  'card': 995,
#  'prison': 996,
#  'tests': 997,
#  'energy': 998,
#  'something': 999,
#  'interest': 1000,
#  ...}

# %%
threshold = 7
total_cnt = len(src_tokenizer.word_index) # 단어의 수
rare_cnt = 0 # 등장 빈도수가 threshold보다 작은 단어의 개수를 카운트
total_freq = 0 # 훈련 데이터의 전체 단어 빈도수 총 합
rare_freq = 0 # 등장 빈도수가 threshold보다 작은 단어의 등장 빈도수의 총 합

# 단어와 빈도수의 쌍(pair)을 key와 value로 받는다.
for key, value in src_tokenizer.word_counts.items():
    total_freq = total_freq + value

    # 단어의 등장 빈도수가 threshold보다 작으면
    if(value < threshold):
        rare_cnt = rare_cnt + 1
        rare_freq = rare_freq + value

print('단어 집합(vocabulary)의 크기 :', total_cnt)
print('등장 빈도가 %s번 이하인 희귀 단어의 수: %s'%(threshold - 1, rare_cnt))
print('단어 집합에서 희귀 단어를 제외시킬 경우의 단어 집합의 크기 %s'%(total_cnt - rare_cnt))
print("단어 집합에서 희귀 단어의 비율:", (rare_cnt / total_cnt)*100)
print("전체 등장 빈도에서 희귀 단어 등장 빈도 비율:", (rare_freq / total_freq)*100)
# Out:
# 단어 집합(vocabulary)의 크기 : 69626
# 등장 빈도가 6번 이하인 희귀 단어의 수: 47437
# 단어 집합에서 희귀 단어를 제외시킬 경우의 단어 집합의 크기 22189
# 단어 집합에서 희귀 단어의 비율: 68.13115790078419
# 전체 등장 빈도에서 희귀 단어 등장 빈도 비율: 3.4892259561941246

# %%
src_vocab = 22000
src_tokenizer = Tokenizer(num_words=src_vocab) # 단어 집합의 크기를 8,000으로 제한
src_tokenizer.fit_on_texts(encoder_input_train) # 단어 집합 재생성

# %%
# 텍스트 시퀀스를 정수 시퀀스로 변환
encoder_input_train = src_tokenizer.texts_to_sequences(encoder_input_train) 
encoder_input_test = src_tokenizer.texts_to_sequences(encoder_input_test)

# 잘 진행되었는지 샘플 출력
print(encoder_input_train[:3])
# Out:
# [[566, 790, 58, 921, 1242, 118, 566, 969, 9, 249, 9, 2417, 683, 223, 354, 3855, 8400, 359, 9, 13813, 310, 7338, 1083, 2097, 360, 683, 13813, 223, 9], [2513, 1816, 61, 1, 730, 683, 2293, 32, 2513, 16720, 5867, 971, 1117, 18, 5867, 971, 1300, 354, 2387, 275, 3603, 1132, 4258, 740, 2555, 160, 2513, 1816, 6398, 236, 5754, 660, 1270, 1414, 32, 1], [176, 15, 331, 8682, 6694, 838, 57, 16721, 108, 1777, 1107, 241, 654, 2007, 26, 18392, 150, 15, 177, 569, 10, 33, 1879, 7245, 1666, 296, 17, 490, 10235, 26, 814, 150, 4884, 1111, 4]]

# %%
tar_tokenizer = Tokenizer()
tar_tokenizer.fit_on_texts(decoder_input_train)

# %%
threshold = 7
total_cnt = len(tar_tokenizer.word_index) # 단어의 수
rare_cnt = 0 # 등장 빈도수가 threshold보다 작은 단어의 개수를 카운트
total_freq = 0 # 훈련 데이터의 전체 단어 빈도수 총 합
rare_freq = 0 # 등장 빈도수가 threshold보다 작은 단어의 등장 빈도수의 총 합

# 단어와 빈도수의 쌍(pair)을 key와 value로 받는다.
for key, value in tar_tokenizer.word_counts.items():
    total_freq = total_freq + value

    # 단어의 등장 빈도수가 threshold보다 작으면
    if(value < threshold):
        rare_cnt = rare_cnt + 1
        rare_freq = rare_freq + value

print('단어 집합(vocabulary)의 크기 :', total_cnt)
print('등장 빈도가 %s번 이하인 희귀 단어의 수: %s'%(threshold - 1, rare_cnt))
print('단어 집합에서 희귀 단어를 제외시킬 경우의 단어 집합의 크기 %s'%(total_cnt - rare_cnt))
print("단어 집합에서 희귀 단어의 비율:", (rare_cnt / total_cnt)*100)
print("전체 등장 빈도에서 희귀 단어 등장 빈도 비율:", (rare_freq / total_freq)*100)
# Out:
# 단어 집합(vocabulary)의 크기 : 30120
# 등장 빈도가 6번 이하인 희귀 단어의 수: 20614
# 단어 집합에서 희귀 단어를 제외시킬 경우의 단어 집합의 크기 9506
# 단어 집합에서 희귀 단어의 비율: 68.43957503320053
# 전체 등장 빈도에서 희귀 단어 등장 빈도 비율: 5.33227213553717

# %%
tar_vocab = 9500
tar_tokenizer = Tokenizer(num_words=tar_vocab) 
tar_tokenizer.fit_on_texts(decoder_input_train)
tar_tokenizer.fit_on_texts(decoder_target_train)

# 텍스트 시퀀스를 정수 시퀀스로 변환
decoder_input_train = tar_tokenizer.texts_to_sequences(decoder_input_train) 
decoder_target_train = tar_tokenizer.texts_to_sequences(decoder_target_train)
decoder_input_test = tar_tokenizer.texts_to_sequences(decoder_input_test)
decoder_target_test = tar_tokenizer.texts_to_sequences(decoder_target_test)

# 잘 변환되었는지 확인
print('input')
print('input ',decoder_input_train[:5])
print('target')
print('decoder ',decoder_target_train[:5])
# Out:
# input
# input  [[1, 237, 1803, 663, 557, 237, 1855, 276, 153], [1, 1160, 998, 573, 4, 1624, 1559, 3, 822, 33], [1, 1448, 1750, 54, 45, 5, 22, 131, 712, 5657], [1, 2271, 124, 1229, 7214, 1094, 16, 528, 54, 543], [1, 3695, 7, 60, 444, 2686, 683, 140, 30]]
# target
# decoder  [[237, 1803, 663, 557, 237, 1855, 276, 153, 2], [1160, 998, 573, 4, 1624, 1559, 3, 822, 33, 2], [1448, 1750, 54, 45, 5, 22, 131, 712, 5657, 2], [2271, 124, 1229, 7214, 1094, 16, 528, 54, 543, 2], [3695, 7, 60, 444, 2686, 683, 140, 30, 2]]

# %%
drop_train = [index for index, sentence in enumerate(decoder_input_train) if len(sentence) == 1]
drop_test = [index for index, sentence in enumerate(decoder_input_test) if len(sentence) == 1]

print('삭제할 훈련 데이터의 개수 :', len(drop_train))
print('삭제할 테스트 데이터의 개수 :', len(drop_test))

encoder_input_train = [sentence for index, sentence in enumerate(encoder_input_train) if index not in drop_train]
decoder_input_train = [sentence for index, sentence in enumerate(decoder_input_train) if index not in drop_train]
decoder_target_train = [sentence for index, sentence in enumerate(decoder_target_train) if index not in drop_train]

encoder_input_test = [sentence for index, sentence in enumerate(encoder_input_test) if index not in drop_test]
decoder_input_test = [sentence for index, sentence in enumerate(decoder_input_test) if index not in drop_test]
decoder_target_test = [sentence for index, sentence in enumerate(decoder_target_test) if index not in drop_test]

print('훈련 데이터의 개수 :', len(encoder_input_train))
print('훈련 레이블의 개수 :', len(decoder_input_train))
print('테스트 데이터의 개수 :', len(encoder_input_test))
print('테스트 레이블의 개수 :', len(decoder_input_test))
# Out:
# 삭제할 훈련 데이터의 개수 : 0
# 삭제할 테스트 데이터의 개수 : 1
# 훈련 데이터의 개수 : 78688
# 훈련 레이블의 개수 : 78688
# 테스트 데이터의 개수 : 19671
# 테스트 레이블의 개수 : 19671

# %%
encoder_input_train = pad_sequences(encoder_input_train, maxlen=text_max_len, padding='post')
encoder_input_test = pad_sequences(encoder_input_test, maxlen=text_max_len, padding='post')
decoder_input_train = pad_sequences(decoder_input_train, maxlen=summary_max_len, padding='post')
decoder_target_train = pad_sequences(decoder_target_train, maxlen=summary_max_len, padding='post')
decoder_input_test = pad_sequences(decoder_input_test, maxlen=summary_max_len, padding='post')
decoder_target_test = pad_sequences(decoder_target_test, maxlen=summary_max_len, padding='post')

# %%
from tensorflow.keras.layers import Input, LSTM, Embedding, Dense, Concatenate, TimeDistributed
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint


# 인코더 설계 시작
embedding_dim = 128
hidden_size = 256

# 인코더
encoder_inputs = Input(shape=(text_max_len,))

# 인코더의 임베딩 층
enc_emb = Embedding(src_vocab, embedding_dim)(encoder_inputs)

# 인코더의 LSTM 1
# encoder_lstm1 = LSTM(hidden_size, return_sequences=True, return_state=True ,dropout = 0.4, recurrent_dropout = 0.4)
encoder_lstm1 = LSTM(hidden_size, return_sequences=True, return_state=True ,dropout = 0.4)
encoder_output1, state_h1, state_c1 = encoder_lstm1(enc_emb)

# 인코더의 LSTM 2
# encoder_lstm2 = LSTM(hidden_size, return_sequences=True, return_state=True, dropout=0.4, recurrent_dropout=0.4)
encoder_lstm2 = LSTM(hidden_size, return_sequences=True, return_state=True, dropout=0.4)
encoder_output2, state_h2, state_c2 = encoder_lstm2(encoder_output1)

# 인코더의 LSTM 3
# encoder_lstm3 = LSTM(hidden_size, return_state=True, return_sequences=True, dropout=0.4, recurrent_dropout=0.4)
encoder_lstm3 = LSTM(hidden_size, return_state=True, return_sequences=True, dropout=0.4)
encoder_outputs, state_h, state_c= encoder_lstm3(encoder_output2)

# %%
# 디코더 설계
decoder_inputs = Input(shape=(None,))

# 디코더의 임베딩 층
dec_emb_layer = Embedding(tar_vocab, embedding_dim)
dec_emb = dec_emb_layer(decoder_inputs)

# 디코더의 LSTM
# decoder_lstm = LSTM(hidden_size, return_sequences=True, return_state=True, dropout=0.4, recurrent_dropout=0.2)
decoder_lstm = LSTM(hidden_size, return_sequences=True, return_state=True, dropout=0.4)
decoder_outputs, _, _ = decoder_lstm(dec_emb, initial_state=[state_h, state_c])

# %%
# 디코더의 출력층
decoder_softmax_layer = Dense(tar_vocab, activation='softmax')
decoder_softmax_outputs = decoder_softmax_layer(decoder_outputs) 

# 모델 정의
model = Model([encoder_inputs, decoder_inputs], decoder_softmax_outputs)
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 60)]         0
# __________________________________________________________________________________________________
# embedding_2 (Embedding)         (None, 60, 128)      2816000     input_3[0][0]
# __________________________________________________________________________________________________
# lstm_4 (LSTM)                   [(None, 60, 256), (N 394240      embedding_2[0][0]
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, None)]       0
# __________________________________________________________________________________________________
# lstm_5 (LSTM)                   [(None, 60, 256), (N 525312      lstm_4[0][0]
# __________________________________________________________________________________________________
# embedding_3 (Embedding)         (None, None, 128)    1216000     input_4[0][0]
# __________________________________________________________________________________________________
# lstm_6 (LSTM)                   [(None, 60, 256), (N 525312      lstm_5[0][0]
# __________________________________________________________________________________________________
# lstm_7 (LSTM)                   [(None, None, 256),  394240      embedding_3[0][0]
#                                                                  lstm_6[0][1]
#                                                                  lstm_6[0][2]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, None, 9500)   2441500     lstm_7[0][0]
# ==================================================================================================
# Total params: 8,312,604
# Trainable params: 8,312,604
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.layers import AdditiveAttention

# 어텐션 층(어텐션 함수)
attn_layer = AdditiveAttention(name='attention_layer')

# 인코더와 디코더의 모든 time step의 hidden state를 어텐션 층에 전달하고 결과를 리턴
attn_out = attn_layer([decoder_outputs, encoder_outputs])


# 어텐션의 결과와 디코더의 hidden state들을 연결
decoder_concat_input = Concatenate(axis=-1, name='concat_layer')([decoder_outputs, attn_out])

# 디코더의 출력층
decoder_softmax_layer = Dense(tar_vocab, activation='softmax')
decoder_softmax_outputs = decoder_softmax_layer(decoder_concat_input)

# 모델 정의
model = Model([encoder_inputs, decoder_inputs], decoder_softmax_outputs)
model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 60)]         0
# __________________________________________________________________________________________________
# embedding_2 (Embedding)         (None, 60, 128)      2816000     input_3[0][0]
# __________________________________________________________________________________________________
# lstm_4 (LSTM)                   [(None, 60, 256), (N 394240      embedding_2[0][0]
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, None)]       0
# __________________________________________________________________________________________________
# lstm_5 (LSTM)                   [(None, 60, 256), (N 525312      lstm_4[0][0]
# __________________________________________________________________________________________________
# embedding_3 (Embedding)         (None, None, 128)    1216000     input_4[0][0]
# __________________________________________________________________________________________________
# lstm_6 (LSTM)                   [(None, 60, 256), (N 525312      lstm_5[0][0]
# __________________________________________________________________________________________________
# lstm_7 (LSTM)                   [(None, None, 256),  394240      embedding_3[0][0]
#                                                                  lstm_6[0][1]
#                                                                  lstm_6[0][2]
# __________________________________________________________________________________________________
# attention_layer (AdditiveAttent (None, None, 256)    256         lstm_7[0][0]
#                                                                  lstm_6[0][0]
# __________________________________________________________________________________________________
# concat_layer (Concatenate)      (None, None, 512)    0           lstm_7[0][0]
#                                                                  attention_layer[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, None, 9500)   4873500     concat_layer[0][0]
# ==================================================================================================
# Total params: 10,744,860
# Trainable params: 10,744,860
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy')
es = EarlyStopping(monitor='val_loss', patience=2, verbose=1)
history = model.fit(x=[encoder_input_train, decoder_input_train], y=decoder_target_train, \
          validation_data=([encoder_input_test, decoder_input_test], decoder_target_test), \
          batch_size=256, callbacks=[es], epochs=5)
# Out:
# Epoch 1/5
# 308/308 [==============================] - 67s 131ms/step - loss: 4.2471 - val_loss: 3.8765
# Epoch 2/5
# 308/308 [==============================] - 40s 131ms/step - loss: 3.7565 - val_loss: 3.6009
# Epoch 3/5
# 308/308 [==============================] - 41s 133ms/step - loss: 3.5182 - val_loss: 3.4270
# Epoch 4/5
# 308/308 [==============================] - 41s 133ms/step - loss: 3.3253 - val_loss: 3.2939
# Epoch 5/5
# 308/308 [==============================] - 41s 133ms/step - loss: 3.1660 - val_loss: 3.1686

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %% [markdown]
# #### Inference 모델 구현

# %%
src_index_to_word = src_tokenizer.index_word # 원문 단어 집합에서 정수 -> 단어를 얻음
tar_word_to_index = tar_tokenizer.word_index # 요약 단어 집합에서 단어 -> 정수를 얻음
tar_index_to_word = tar_tokenizer.index_word # 요약 단어 집합에서 정수 -> 단어를 얻음

# %%
# 인코더 설계
encoder_model = Model(inputs=encoder_inputs, outputs=[encoder_outputs, state_h, state_c])

# 이전 시점의 상태들을 저장하는 텐서
decoder_state_input_h = Input(shape=(hidden_size,))
decoder_state_input_c = Input(shape=(hidden_size,))

dec_emb2 = dec_emb_layer(decoder_inputs)

# 문장의 다음 단어를 예측하기 위해서 초기 상태(initial_state)를 이전 시점의 상태로 사용. 이는 뒤의 함수 decode_sequence()에 구현
# 훈련 과정에서와 달리 LSTM의 리턴하는 은닉 상태와 셀 상태인 state_h와 state_c를 버리지 않음.
decoder_outputs2, state_h2, state_c2 = decoder_lstm(dec_emb2, initial_state=[decoder_state_input_h, decoder_state_input_c])

# %%
# 어텐션 함수
decoder_hidden_state_input = Input(shape=(text_max_len, hidden_size))
attn_out_inf = attn_layer([decoder_outputs2, decoder_hidden_state_input])
decoder_inf_concat = Concatenate(axis=-1, name='concat')([decoder_outputs2, attn_out_inf])

# 디코더의 출력층
decoder_outputs2 = decoder_softmax_layer(decoder_inf_concat) 

# 최종 디코더 모델
decoder_model = Model(
    [decoder_inputs] + [decoder_hidden_state_input,decoder_state_input_h, decoder_state_input_c],
    [decoder_outputs2] + [state_h2, state_c2])

# %%
def decode_sequence(input_seq):
    # 입력으로부터 인코더의 상태를 얻음
    e_out, e_h, e_c = encoder_model.predict(input_seq)

     # <SOS>에 해당하는 토큰 생성
    target_seq = np.zeros((1,1))
    target_seq[0, 0] = tar_word_to_index['sostoken']

    stop_condition = False
    decoded_sentence = ''
    while not stop_condition: # stop_condition이 True가 될 때까지 루프 반복

        output_tokens, h, c = decoder_model.predict([target_seq] + [e_out, e_h, e_c])
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_token = tar_index_to_word[sampled_token_index]

        if (sampled_token!='eostoken'):
            decoded_sentence += ' '+sampled_token

        #  <eos>에 도달하거나 최대 길이를 넘으면 중단.
        if (sampled_token == 'eostoken'  or len(decoded_sentence.split()) >= (summary_max_len-1)):
            stop_condition = True

        # 길이가 1인 타겟 시퀀스를 업데이트
        target_seq = np.zeros((1,1))
        target_seq[0, 0] = sampled_token_index

        # 상태를 업데이트 합니다.
        e_h, e_c = h, c

    return decoded_sentence

# %%
# 원문의 정수 시퀀스를 텍스트 시퀀스로 변환
def seq2text(input_seq):
    temp=''
    for i in input_seq:
        if (i!=0):
            temp = temp + src_index_to_word[i]+' '
    return temp

# 요약문의 정수 시퀀스를 텍스트 시퀀스로 변환
def seq2summary(input_seq):
    temp=''
    for i in input_seq:
        if ((i!=0 and i!=tar_word_to_index['sostoken']) and i!=tar_word_to_index['eostoken']):
            temp = temp + tar_index_to_word[i] + ' '
    return temp

# %%
for i in range(50, 100):
    print("원문 :", seq2text(encoder_input_test[i]))
    print("실제 요약 :", seq2summary(decoder_input_test[i]))
    print("예측 요약 :", decode_sequence(encoder_input_test[i].reshape(1, text_max_len)))
    print("\n")
# Out:
# 원문 : addressing gathering village gujarat pm modi said dream country celebrates years independence family house homes built pradhan mantri awas yojana high quality nobody pay bribe added
# 실제 요약 : there should be no family without own home by pm modi
# 예측 요약 :  pm modi to visit pm modi for pm modi
#
#
# 원문 : israel monday said jets attacked syrian anti aircraft missile launcher fired aircraft patrolling lebanese air space reconnaissance mission see incident clear provocation allow israel added missile launch second time israeli jets engaged syrian anti aircraft missiles year nnn
# 실제 요약 : israeli jets attack syrian missile in
# 예측 요약 :  us to build us to us missile missile
#
#
# 원문 : post mortem reports claimed bjp worker found hanging electricity pole west bengal committed suicide father said trinamool congress workers responsible death kumar father asked suicide problem life bjp called death political murder
# 실제 요약 : tmc men killed son dad of bjp worker found hanging in wb
# 예측 요약 :  bjp mla arrested for raping bjp mla in rape
#
#
# 원문 : winners fifa world cups italy eliminated first round edition played year gap due world war ii world cup trophy holders brazil made group stage exit defending champions france italy spain made first round exits respectively
# 실제 요약 : which defending champs have made st round world cup exits
# 예측 요약 :  world cup city to win world cup in wc
#
#
# 원문 : union minister dharmendra pradhan tuesday said pakistan country indian forces give reply adding pakistan country deserves friendly relations country pradhan said people want talks initially honesty pakistan crossing limits
# 실제 요약 : pakistan is country union minister pradhan
# 예측 요약 :  india to be with india to india india
#
#
# 원문 : responding rti query uidai said aadhaar card holder lock biometrics may opt suggested supreme court september apex court directed persons enrolled enforcement aadhaar act two years ago need given option exit aadhaar
# 실제 요약 : aadhaar holder can only lock not opt out uidai
# 예측 요약 :  aadhaar can be aadhaar to be aadhaar to aadhaar
#
#
# 원문 : malayalam films displaying statutory warning showing scenes depict violence women comes kerala state human rights commission issued directive regional office central board film certification add warning violence women punishable offence decision made within days
# 실제 요약 : malayalam films to show warnings for violent scenes on women
# 예측 요약 :  tn govt to stop anti sterlite attack
#
#
# 원문 : chinese envoy luo zhaohui said china could help maintain peace india pakistan indian government said matters related india pakistan relations purely bilateral scope involvement third country received suggestion chinese government added zhaohui called trilateral cooperation nations
# 실제 요약 : indo pak ties have no space for rd country india to china
# 예측 요약 :  india to be with india to india china
#
#
# 원문 : indian origin finance consultant sentenced eight years prison raping year old woman night drinking colleagues year old found guilty carrying woman shoulder denied entry nightclub central london drunk raping
# 실제 요약 : indian origin gets yr jail for raping yr old
# 예측 요약 :  yr old girl raped for raping year old girl
#
#
# 원문 : singer sonu nigam shared video seen singing youtube personality dhinchak pooja song dilon ka shooter sonu wrote singing track like would sung kumar sanu added shared video despite son idea
# 실제 요약 : sonu nigam sings dhinchak pooja song ka shooter
# 예측 요약 :  video shows his song with her her
#
#
# 원문 : claiming central government policy kashmir pakistan former union minister arun monday said one trick horse knows divide hindus muslims country also termed surgical strikes carried indian forces pakistan strike
# 실제 요약 : centre wants to hindus and muslims says ex minister
# 예측 요약 :  pak govt to be with india to india
#
#
# 원문 : president donald trump threatened withdraw us world trade organisation shape claiming treats country badly added agreement establish wto single worst trade deal ever made trump repeatedly claimed wto unfair us global trade
# 실제 요약 : trump threatens to withdraw us from world trade organisation
# 예측 요약 :  trump to be with us to trump
#
#
# 원문 : singh director sanjay dutt upcoming film said make dutt dance around trees romantic film showing young lover boy playing around age love romance happen age give new definition love film said singh
# 실제 요약 : dutt will not dance around trees in my upcoming film director
# 예측 요약 :  salman khan to play film in film film reports
#
#
# 원문 : video shows maharashtra chief minister devendra fadnavis wife fadnavis crossed india first domestic cruise safety range clicked selfie cautioned security personnel onboard cruise crossed safety range cruise service mumbai goa launched october
# 실제 요약 : maharashtra cm wife crosses cruise security range takes selfie
# 예측 요약 :  man who killed in delhi airport for crore
#
#
# 원문 : meth addicted snake spent seven months corrective services wildlife care centre australia set released rehab reptile seized raid drug lab reportedly developed habit absorbing fumes particles manufacturing ice lab skin nn
# 실제 요약 : meth snake to be released from rehab
# 예측 요약 :  new zealand to be in india
#
#
# 원문 : british government announced dedicated national security unit combat fake news disinformation unit headed uk cabinet office consistently flag false information social media platforms systematically deter adversaries help deliver national security priorities prime minister theresa may spokesperson said
# 실제 요약 : uk government announces dedicated unit to combat fake news
# 예측 요약 :  uk govt to use aadhaar to use for aadhaar
#
#
# 원문 : international cricket council thursday confirmed member countries receive international status women matches awarded international status july men matches would given status january member nation receive world ranking well
# 실제 요약 : all icc member nations to get international status
# 예측 요약 :  indian captain to play in india for years
#
#
# 원문 : three year old girl fell feet deep playing outside grandfather house bihar munger tuesday girl safe might take four hours rescue said official provided oxygen made arrangements safety placed rods ensure fall added nn
# 실제 요약 : year old girl falls into feet deep in bihar
# 예측 요약 :  man kills year old girl for being in delhi
#
#
# 원문 : australia set pass legislation giving police intelligence agencies access encrypted messages platforms whatsapp government reached principle agreement changes made include limiting application powers bill serious offences shadow attorney general mark said technology giants facebook google oppose
# 실제 요약 : new australia law to give police access to chat
# 예측 요약 :  us to use us to use for us to us
#
#
# 원문 : iran banned government bodies using foreign based messaging apps communicate citizens iran state media reported banned messaging apps include telegram used crore iranians several messaging apps used iran mobilise support anti government protests last year
# 실제 요약 : iran bans govt bodies from using foreign messaging apps
# 예측 요약 :  us bans us to ban for us to stop us
#
#
# 원문 : new experimental vaccine used try control ebola outbreak african nation congo death toll increased current outbreak total cases fever including confirmed cases reported congo ninth ebola outbreak since disease first identified
# 실제 요약 : congo to use as deaths rise to
# 예측 요약 :  us to build first ever in india
#
#
# 원문 : many people killed injured struck lightning different parts west bengal sunday night killed outside houses working fields lightning struck disaster management officials said precautionary measures taken alerts issued based weather department warnings officials added
# 실제 요약 : killed after being struck by lightning in west bengal
# 예측 요약 :  killed injured in blast in kabul
#
#
# 원문 : david un special rapporteur freedom opinion expression called us president donald trump worst perpetrator false information country calling governments real offenders disinformation said journalists report fake news spread platforms like facebook twitter google help reduce spam bot accounts censor content
# 실제 요약 : donald trump worst of fake news un official
# 예측 요약 :  trump asks us to use us to us trump
#
#
# 원문 : tenth black rhino died kenya wildlife workers relocated animals new national park start new population area animals death blamed negligence poor communication coordination among officers involved transfer meanwhile th rhino attacked lion critical
# 실제 요약 : endangered moved to start new population die
# 예측 요약 :  us to get its first ever in us
#
#
# 원문 : haryana police thursday arrested two eight men booked allegedly raping pregnant goat july village district state accused truck drivers early twenties alleged history villagers beaten three eight accused owner goat caught act
# 실제 요약 : of men accused of raping pregnant goat arrested
# 예측 요약 :  man arrested for raping minor in delhi
#
#
# 원문 : bharti airtel chairman sunil mittal said company would open acquisition talks aircel added aircel options either go combined entity vodafone idea airtel whenever possibility conversation doubt part conversation added
# 실제 요약 : airtel open to acquisition talks with aircel sunil mittal
# 예측 요약 :  tata board appoints new tata board to be down
#
#
# 원문 : year old girl died falling water ride manor theme park england tuesday manor director george bryan said girl school trip incident occurred according reports stood ride hit head falling water
# 실제 요약 : year old girl dies after falling from theme park ride
# 예측 요약 :  man arrested for molesting woman in mumbai
#
#
# 원문 : us government able find evidence pakistan government aware attacks mastermind osama bin laden presence country ex us president barack obama said us approach viewing connections terrorist organisations official entities pakistan consistent hard problem solve obama added
# 실제 요약 : no evidence pak knew about osama bin laden presence obama
# 예측 요약 :  us prez calls us to us us to us
#
#
# 원문 : astronomers discovered first evidence star formation winds expelled supermassive black holes black holes galactic matter heating surrounding gas process expel form powerful dense winds discovery made using large telescope chile based observatory studying colliding galaxies million light years away
# 실제 요약 : scientists find st proof of star birth in black hole winds
# 예측 요약 :  scientists make first ever ever
#
#
# 원문 : australia catholic church rejected suggestions commission make priests voluntary end secrecy confession argued ending would necessarily end child abuse royal commission institutional responses child sexual abuse said largest number perpetrators abused children australian institutions catholic churches
# 실제 요약 : aus church rejects calls for for priests
# 예측 요약 :  pope apologises for sexual abuse of abuse
#
#
# 원문 : us president donald trump threatened stop assistance pakistan country foreign minister khawaja asif said let world know truth difference facts fiction also said pakistan respond president trump tweet shortly given us nothing lies deceit thinking leaders fools trump said
# 실제 요약 : will let world know difference between facts fiction pak
# 예측 요약 :  trump calls us envoy to visit us prez
#
#
# 원문 : actress swara bhasker said unfair judge independent films based opening weekend collections usually feature actors like salman khan shah rukh khan hrithik roshan aamir khan films need weeks run content driven work word mouth kicks audiences like added swara
# 실제 요약 : no srk aamir in films for st weekend earnings swara
# 예측 요약 :  do not want to make my film on film with film
#
#
# 원문 : singer enrique partner former tennis player anna shared first pictures newborn twins nicholas lucy twitter keeping pregnancy secret announced birth twins december last year enrique anna reportedly dating since met sets music video escape
# 실제 요약 : anna share first pics of newborn twins
# 예측 요약 :  ex man who was out of his child
#
#
# 원문 : twinkle khanna asked write bollywood said bollywood boring write columns short stories find interesting seen would write familiar added twinkle said always bollywood
# 실제 요약 : it is boring to me twinkle on not writing on bollywood
# 예측 요약 :  do not want to be with my films to be with me sonu
#
#
# 원문 : us headquartered startup displayed world first commercial foldable smartphone consumer electronics show las vegas device inch display works snapdragon runs customised version android pie said already sale china yuan ordered online
# 실제 요약 : world st commercial foldable smartphone shown at ces
# 예측 요약 :  samsung unveils world largest startup
#
#
# 원문 : government proposed clearing india civil services examination allotted service well cadre state three month foundation course existing rules qualifying candidates immediately allocated service cadre based ranks secure examination conducted india services
# 실제 요약 : civil service may be allotted only post month course
# 예측 요약 :  govt to be to be for govt to govt
#
#
# 원문 : talking recent sexual harassment allegations various bollywood celebrities pooja bhatt said every man cannot sexual predator every woman necessarily victim sometimes also perpetrator paint every man brush unfair added responsible naming people avoid media trial added
# 실제 요약 : not every man sexual not every woman victim pooja
# 예측 요약 :  weinstein slams sexual harassment against sexual harassment
#
#
# 원문 : ncert released manual guiding schools ensure sensitive needs students minority communities stating students find prayers school assemblies manual advised school committees celebrate festivals observed religious minorities also directed schools monitor attendance students disadvantaged groups
# 실제 요약 : ncert book on making schools for minorities
# 예측 요약 :  cbse students to be students to students
#
#
# 원문 : german astronaut alexander gerst reportedly put finger hole space station soyuz capsule crew members used tape close nasa earlier confirmed two millimetre wide tear leaking oxygen space created minor pressure drop space agency said six member crew featuring three americans two russians gerst safe
# 실제 요약 : astronaut space station leak with finger before using tape
# 예측 요약 :  scientists make first ever ever hole in space
#
#
# 원문 : poland arrested huawei employee former polish security official alleged spying china polish authorities said friday huawei employee chinese citizen responsible sales public sector clients poland according poland state broadcaster comes amid allegations huawei devices could used china spying countries
# 실제 요약 : huawei worker arrested in poland over alleged spying for china
# 예측 요약 :  us man arrested for stealing fake fake fake fake
#
#
# 원문 : kaur chhattisgarh private channel read breaking news husband death road accident saturday got sense husband vehicle read bulletin came studio started calling relatives senior editor said incident
# 실제 요약 : tv anchor reads out news of her husband death in accident
# 예측 요약 :  man who killed for being killed in mumbai
#
#
# 원문 : social media major facebook wednesday posted profit billion previous year facebook also reported total revenue growth quarter billion company shares rose hours trading releasing earnings report
# 실제 요약 : facebook profit jumps to billion in
# 예측 요약 :  samsung loses billion in billion in us
#
#
# 원문 : fifa world cup germany mario gomez uses far left match superstition teammate julian holds bag locker perfume gives feeling happiness england dele alli using shin guards worn since
# 실제 요약 : what are players following in fifa world cup
# 예측 요약 :  football player to play world cup in wc
#
#
# 원문 : competition commission india thursday imposed fine crore google search bias latest regulatory setback world popular internet search engine cci said google abusing dominance online web search online search advertising markets fine deposited within days added
# 실제 요약 : google fined crore by indian watchdog for search bias
# 예측 요약 :  us firm to invest mn in us for bn
#
#
# 원문 : taking dig pm narendra modi congress leader raj babbar thursday said indian rupee fallen much dollar nearing beloved mother age used say indian rupee fallen much nearing age pm added
# 실제 요약 : rupee closer to the age of pm modi mother raj babbar
# 예측 요약 :  pm modi to pm modi for pm modi
#
#
# 원문 : united states president donald trump misspelled twice correcting third tweet thursday morning trump tweeted bad one change tones twice correcting spelling also used correcting spelling days misspelling heal heel twitter
# 실제 요약 : trump misspells too twice before it rd time
# 예측 요약 :  trump mocks trump for trump
#
#
# 원문 : youth congress activists odisha saturday hurled eggs union agriculture minister radha mohan singh vehicle protest death five farmers madhya pradesh mandsaur district incident took place union minister left state guest house way attend programme sabka sath sabka
# 실제 요약 : eggs hurled at agriculture min car over farmers deaths
# 예측 요약 :  bjp leader to be in mp to protest in mp
#
#
# 원문 : nasa recently shared action footage spacewalk performed us astronauts peggy whitson shane outside international space station march maintenance work one station shields accidentally lost however astronauts installed previously removed cover providing thermal protection space debris cover port
# 실제 요약 : nasa shares first person view of spacewalk
# 예측 요약 :  nasa to launch first ever ever ever in space
#
#
# 원문 : former infosys cfo mohandas pai said india needs chief information officer prime minister office integrating strategies policies related various departments said role important large part financial transactions technology india likely inter linked aadhaar number
# 실제 요약 : pmo should have chief information officer post mohandas pai
# 예측 요약 :  infosys to be down as infosys ceo
#
#
# 원문 : former prime minister manmohan singh saturday said adventure demonetisation required neither technically economically said demonetisation involved withdrawing almost currency circulation bound fallout seeing said economy slowed due demonetisation
# 실제 요약 : note ban was not required at all manmohan singh
# 예측 요약 :  india to be with pm modi on gst

# %% [markdown]
# #### 추출적 요약

# %%
import requests
from summa.summarizer import summarize

# %%
data.head()

# %%
text = '\n'.join(clean_text)

# %%
print(text[:1500])
# Out:
# saurav kant alumnus upgrad iiit pg program machine learning artificial intelligence sr systems engineer infosys almost years work experience program upgrad degree career support helped transition data scientist tech mahindra salary hike upgrad online power learning powered lakh careers
# kunal shah credit card bill payment platform cred gave users chance win free food swiggy one year pranav kaushik delhi techie bagged reward spending cred coins users get one cred coin per rupee bill paid used avail rewards brands like ixigo bookmyshow ubereats cult fit
# new zealand defeated india wickets fourth odi hamilton thursday win first match five match odi series india lost international match rohit sharma captaincy consecutive victories dating back march match witnessed india getting seventh lowest total odi cricket history
# aegon life iterm insurance plan customers enjoy tax benefits premiums paid save taxes plan provides life cover age years also customers options insure critical illnesses disability accidental death benefit rider life cover age years
# speaking sexual harassment allegations rajkumar hirani sonam kapoor said known hirani many years true metoo movement get derailed metoo movement always believe woman case need reserve judgment added hirani accused assistant worked sanju
# pakistani singer rahat fateh ali khan denied receiving notice enforcement directorate allegedly smuggling foreign currency india would better authorities would served notice first publicised reads press rel

# %%
print('Summary:')
print(summarize(text, ratio=0.005))
# Out:
# Summary:

# %%
print('Summary:')
print(summarize(text, ratio=0.005, split=True))

# %%
print('Summary:')
print(summarize(text, words=50))
